# %% [markdown]
# # N-Gram Model
# Create a character N-gram model and a words N-gram model in python to develop automatic text filter using N-Grams

# %%
import nltk
import numpy as np
import random
import string
import bs4 as bs
import urllib.request
import re
import nltk
nltk.download('punkt')

# %%
raw_html = urllib.request.urlopen('https://en.wikipedia.org/wiki/Machine_learning')
raw_html = raw_html.read()
article_html = bs.BeautifulSoup(raw_html, 'lxml')
article_paragraphs = article_html.find_all('p')
article_text = ''

# %% [markdown]
# **WORD N-GRAM**

# %%
for para in article_paragraphs:
  article_text += para.text
article_text = article_text.lower()
article_text = re.sub(r'[^A-Za-z. ]', '', article_text)

# %%
ngrams = {}
chars = 4
for i in range(len(article_text)-chars):
  seq = article_text[i:i+chars]
  print(seq)
  if seq not in ngrams.keys():
    ngrams[seq] = []
  ngrams[seq].append(article_text[i+chars])

curr_sequence = article_text[0:chars]
output = curr_sequence
# Out:
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng m
# g ml
#  ml
# ml i
# l is
#  is
# is a
# s a
#  a f
# a fi
#  fie
# fiel
# ield
# eld
# ld o
# d of
#  of
# of i
# f in
#  inq
# inqu
# nqui
# quir
# uiry
# iry
# ry d
# y de
#  dev
# devo
# evot
# vote
# oted
# ted
# ed t
# d to
#  to
# to u
# o un
#  und
# unde
# nder
# ders
# erst
# rsta
# stan
# tand
# andi
# ndin
# ding
# ing
# ng a
# g an
#  and
# and
# nd b
# d bu
#  bui
# buil
# uild
# ildi
# ldin
# ding
# ing
# ng m
# g me
#  met
# meth
# etho
# thod
# hods
# ods
# ds t
# s th
#  tha
# that
# hat
# at l
# t le
#  lea
# lear
# earn
# arn
# rn t
# n th
#  tha
# that
# hat
# at i
# t is
#  is
# is m
# s me
#  met
# meth
# etho
# thod
# hods
# ods
# ds t
# s th
#  tha
# that
# hat
# at l
# t le
#  lev
# leve
# ever
# vera
# erag
# rage
# age
# ge d
# e da
#  dat
# data
# ata
# ta t
# a to
#  to
# to i
# o im
#  imp
# impr
# mpro
# prov
# rove
# ove
# ve p
# e pe
#  per
# perf
# erfo
# rfor
# form
# orma
# rman
# manc
# ance
# nce
# ce o
# e on
#  on
# on s
# n so
#  som
# some
# ome
# me s
# e se
#  set
# set
# et o
# t of
#  of
# of t
# f ta
#  tas
# task
# asks
# sks.
# ks.
# s. i
# . it
#  it
# it i
# t is
#  is
# is s
# s se
#  see
# seen
# een
# en a
# n as
#  as
# as a
# s a
#  a p
# a pa
#  par
# part
# art
# rt o
# t of
#  of
# of a
# f ar
#  art
# arti
# rtif
# tifi
# ific
# fici
# icia
# cial
# ial
# al i
# l in
#  int
# inte
# ntel
# tell
# elli
# llig
# lige
# igen
# genc
# ence
# nce.
# ce.
# e. m
# . ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms b
# s bu
#  bui
# buil
# uild
# ild
# ld a
# d a
#  a m
# a mo
#  mod
# mode
# odel
# del
# el b
# l ba
#  bas
# base
# ased
# sed
# ed o
# d on
#  on
# on s
# n sa
#  sam
# samp
# ampl
# mple
# ple
# le d
# e da
#  dat
# data
# ata
# ta k
# a kn
#  kno
# know
# nown
# own
# wn a
# n as
#  as
# as t
# s tr
#  tra
# trai
# rain
# aini
# inin
# ning
# ing
# ng d
# g da
#  dat
# data
# ata
# ta i
# a in
#  in
# in o
# n or
#  ord
# orde
# rder
# der
# er t
# r to
#  to
# to m
# o ma
#  mak
# make
# ake
# ke p
# e pr
#  pre
# pred
# redi
# edic
# dict
# icti
# ctio
# tion
# ions
# ons
# ns o
# s or
#  or
# or d
# r de
#  dec
# deci
# ecis
# cisi
# isio
# sion
# ions
# ons
# ns w
# s wi
#  wit
# with
# itho
# thou
# hout
# out
# ut b
# t be
#  bei
# bein
# eing
# ing
# ng e
# g ex
#  exp
# expl
# xpli
# plic
# lici
# icit
# citl
# itly
# tly
# ly p
# y pr
#  pro
# prog
# rogr
# ogra
# gram
# ramm
# amme
# mmed
# med
# ed t
# d to
#  to
# to d
# o do
#  do
# do s
# o so
#  so.
# so.
# o. m
# . ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms a
# s ar
#  are
# are
# re u
# e us
#  use
# used
# sed
# ed i
# d in
#  in
# in a
# n a
#  a w
# a wi
#  wid
# wide
# ide
# de v
# e va
#  var
# vari
# arie
# riet
# iety
# ety
# ty o
# y of
#  of
# of a
# f ap
#  app
# appl
# ppli
# plic
# lica
# icat
# cati
# atio
# tion
# ions
# ons
# ns s
# s su
#  suc
# such
# uch
# ch a
# h as
#  as
# as i
# s in
#  in
# in m
# n me
#  med
# medi
# edic
# dici
# icin
# cine
# ine
# ne e
# e em
#  ema
# emai
# mail
# ail
# il f
# l fi
#  fil
# filt
# ilte
# lter
# teri
# erin
# ring
# ing
# ng s
# g sp
#  spe
# spee
# peec
# eech
# ech
# ch r
# h re
#  rec
# reco
# ecog
# cogn
# ogni
# gnit
# niti
# itio
# tion
# ion
# on a
# n an
#  and
# and
# nd c
# d co
#  com
# comp
# ompu
# mput
# pute
# uter
# ter
# er v
# r vi
#  vis
# visi
# isio
# sion
# ion
# on w
# n wh
#  whe
# wher
# here
# ere
# re i
# e it
#  it
# it i
# t is
#  is
# is d
# s di
#  dif
# diff
# iffi
# ffic
# ficu
# icul
# cult
# ult
# lt o
# t or
#  or
# or u
# r un
#  unf
# unfe
# nfea
# feas
# easi
# asib
# sibl
# ible
# ble
# le t
# e to
#  to
# to d
# o de
#  dev
# deve
# evel
# velo
# elop
# lop
# op c
# p co
#  con
# conv
# onve
# nven
# vent
# enti
# ntio
# tion
# iona
# onal
# nal
# al a
# l al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms t
# s to
#  to
# to p
# o pe
#  per
# perf
# erfo
# rfor
# form
# orm
# rm t
# m th
#  the
# the
# he n
# e ne
#  nee
# need
# eede
# eded
# ded
# ed t
# d ta
#  tas
# task
# asks
# sks.
# ks.a
# s.a
# .a s
# a su
#  sub
# subs
# ubse
# bset
# set
# et o
# t of
#  of
# of m
# f ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng i
# g is
#  is
# is c
# s cl
#  clo
# clos
# lose
# osel
# sely
# ely
# ly r
# y re
#  rel
# rela
# elat
# late
# ated
# ted
# ed t
# d to
#  to
# to c
# o co
#  com
# comp
# ompu
# mput
# puta
# utat
# tati
# atio
# tion
# iona
# onal
# nal
# al s
# l st
#  sta
# stat
# tati
# atis
# tist
# isti
# stic
# tics
# ics
# cs w
# s wh
#  whi
# whic
# hich
# ich
# ch f
# h fo
#  foc
# focu
# ocus
# cuse
# uses
# ses
# es o
# s on
#  on
# on m
# n ma
#  mak
# maki
# akin
# king
# ing
# ng p
# g pr
#  pre
# pred
# redi
# edic
# dict
# icti
# ctio
# tion
# ions
# ons
# ns u
# s us
#  usi
# usin
# sing
# ing
# ng c
# g co
#  com
# comp
# ompu
# mput
# pute
# uter
# ters
# ers
# rs b
# s bu
#  but
# but
# ut n
# t no
#  not
# not
# ot a
# t al
#  all
# all
# ll m
# l ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng i
# g is
#  is
# is s
# s st
#  sta
# stat
# tati
# atis
# tist
# isti
# stic
# tica
# ical
# cal
# al l
# l le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing.
# ng.
# g. t
# . th
#  the
# the
# he s
# e st
#  stu
# stud
# tudy
# udy
# dy o
# y of
#  of
# of m
# f ma
#  mat
# math
# athe
# them
# hema
# emat
# mati
# atic
# tica
# ical
# cal
# al o
# l op
#  opt
# opti
# ptim
# timi
# imiz
# miza
# izat
# zati
# atio
# tion
# ion
# on d
# n de
#  del
# deli
# eliv
# live
# iver
# vers
# ers
# rs m
# s me
#  met
# meth
# etho
# thod
# hods
# ods
# ds t
# s th
#  the
# theo
# heor
# eory
# ory
# ry a
# y an
#  and
# and
# nd a
# d ap
#  app
# appl
# ppli
# plic
# lica
# icat
# cati
# atio
# tion
# ion
# on d
# n do
#  dom
# doma
# omai
# main
# ains
# ins
# ns t
# s to
#  to
# to t
# o th
#  the
# the
# he f
# e fi
#  fie
# fiel
# ield
# eld
# ld o
# d of
#  of
# of m
# f ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing.
# ng.
# g. d
# . da
#  dat
# data
# ata
# ta m
# a mi
#  min
# mini
# inin
# ning
# ing
# ng i
# g is
#  is
# is a
# s a
#  a r
# a re
#  rel
# rela
# elat
# late
# ated
# ted
# ed f
# d fi
#  fie
# fiel
# ield
# eld
# ld o
# d of
#  of
# of s
# f st
#  stu
# stud
# tudy
# udy
# dy f
# y fo
#  foc
# focu
# ocus
# cusi
# usin
# sing
# ing
# ng o
# g on
#  on
# on e
# n ex
#  exp
# expl
# xplo
# plor
# lora
# orat
# rato
# ator
# tory
# ory
# ry d
# y da
#  dat
# data
# ata
# ta a
# a an
#  ana
# anal
# naly
# alys
# lysi
# ysis
# sis
# is t
# s th
#  thr
# thro
# hrou
# roug
# ough
# ugh
# gh u
# h un
#  uns
# unsu
# nsup
# supe
# uper
# perv
# ervi
# rvis
# vise
# ised
# sed
# ed l
# d le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing.
# ng.
# g. s
# . so
#  som
# some
# ome
# me i
# e im
#  imp
# impl
# mple
# plem
# leme
# emen
# ment
# enta
# ntat
# tati
# atio
# tion
# ions
# ons
# ns o
# s of
#  of
# of m
# f ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng u
# g us
#  use
# use
# se d
# e da
#  dat
# data
# ata
# ta a
# a an
#  and
# and
# nd n
# d ne
#  neu
# neur
# eura
# ural
# ral
# al n
# l ne
#  net
# netw
# etwo
# twor
# work
# orks
# rks
# ks i
# s in
#  in
# in a
# n a
#  a w
# a wa
#  way
# way
# ay t
# y th
#  tha
# that
# hat
# at m
# t mi
#  mim
# mimi
# imic
# mics
# ics
# cs t
# s th
#  the
# the
# he w
# e wo
#  wor
# work
# orki
# rkin
# king
# ing
# ng o
# g of
#  of
# of a
# f a
#  a b
# a bi
#  bio
# biol
# iolo
# olog
# logi
# ogic
# gica
# ical
# cal
# al b
# l br
#  bra
# brai
# rain
# ain.
# in.
# n.
# .  i
#   in
#  in
# in i
# n it
#  its
# its
# ts a
# s ap
#  app
# appl
# ppli
# plic
# lica
# icat
# cati
# atio
# tion
# ion
# on a
# n ac
#  acr
# acro
# cros
# ross
# oss
# ss b
# s bu
#  bus
# busi
# usin
# sine
# ines
# ness
# ess
# ss p
# s pr
#  pro
# prob
# robl
# oble
# blem
# lems
# ems
# ms m
# s ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng i
# g is
#  is
# is a
# s al
#  als
# also
# lso
# so r
# o re
#  ref
# refe
# efer
# ferr
# erre
# rred
# red
# ed t
# d to
#  to
# to a
# o as
#  as
# as p
# s pr
#  pre
# pred
# redi
# edic
# dict
# icti
# ctiv
# tive
# ive
# ve a
# e an
#  ana
# anal
# naly
# alyt
# lyti
# ytic
# tics
# ics.
# cs.l
# s.le
# .lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms w
# s wo
#  wor
# work
# ork
# rk o
# k on
#  on
# on t
# n th
#  the
# the
# he b
# e ba
#  bas
# basi
# asis
# sis
# is t
# s th
#  tha
# that
# hat
# at s
# t st
#  str
# stra
# trat
# rate
# ateg
# tegi
# egie
# gies
# ies
# es a
# s al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms a
# s an
#  and
# and
# nd i
# d in
#  inf
# infe
# nfer
# fere
# eren
# renc
# ence
# nces
# ces
# es t
# s th
#  tha
# that
# hat
# at w
# t wo
#  wor
# work
# orke
# rked
# ked
# ed w
# d we
#  wel
# well
# ell
# ll i
# l in
#  in
# in t
# n th
#  the
# the
# he p
# e pa
#  pas
# past
# ast
# st a
# t ar
#  are
# are
# re l
# e li
#  lik
# like
# ikel
# kely
# ely
# ly t
# y to
#  to
# to c
# o co
#  con
# cont
# onti
# ntin
# tinu
# inue
# nue
# ue w
# e wo
#  wor
# work
# orki
# rkin
# king
# ing
# ng w
# g we
#  wel
# well
# ell
# ll i
# l in
#  in
# in t
# n th
#  the
# the
# he f
# e fu
#  fut
# futu
# utur
# ture
# ure.
# re.
# e. t
# . th
#  the
# thes
# hese
# ese
# se i
# e in
#  inf
# infe
# nfer
# fere
# eren
# renc
# ence
# nces
# ces
# es c
# s ca
#  can
# can
# an b
# n be
#  be
# be o
# e ob
#  obv
# obvi
# bvio
# viou
# ious
# ous
# us s
# s su
#  suc
# such
# uch
# ch a
# h as
#  as
# as s
# s si
#  sin
# sinc
# ince
# nce
# ce t
# e th
#  the
# the
# he s
# e su
#  sun
# sun
# un r
# n ro
#  ros
# rose
# ose
# se e
# e ev
#  eve
# ever
# very
# ery
# ry m
# y mo
#  mor
# morn
# orni
# rnin
# ning
# ing
# ng f
# g fo
#  for
# for
# or t
# r th
#  the
# the
# he l
# e la
#  las
# last
# ast
# st
# t  d
#   da
#  day
# days
# ays
# ys i
# s it
#  it
# it w
# t wi
#  wil
# will
# ill
# ll p
# l pr
#  pro
# prob
# roba
# obab
# babl
# ably
# bly
# ly r
# y ri
#  ris
# rise
# ise
# se t
# e to
#  tom
# tomo
# omor
# morr
# orro
# rrow
# row
# ow m
# w mo
#  mor
# morn
# orni
# rnin
# ning
# ing
# ng a
# g as
#  as
# as w
# s we
#  wel
# well
# ell.
# ll.
# l. t
# . th
#  the
# they
# hey
# ey c
# y ca
#  can
# can
# an b
# n be
#  be
# be n
# e nu
#  nua
# nuan
# uanc
# ance
# nced
# ced
# ed s
# d su
#  suc
# such
# uch
# ch a
# h as
#  as
# as x
# s x
#  x o
# x of
#  of
# of f
# f fa
#  fam
# fami
# amil
# mili
# ilie
# lies
# ies
# es h
# s ha
#  hav
# have
# ave
# ve g
# e ge
#  geo
# geog
# eogr
# ogra
# grap
# raph
# aphi
# phic
# hica
# ical
# call
# ally
# lly
# ly s
# y se
#  sep
# sepa
# epar
# para
# arat
# rate
# ate
# te s
# e sp
#  spe
# spec
# peci
# ecie
# cies
# ies
# es w
# s wi
#  wit
# with
# ith
# th c
# h co
#  col
# colo
# olor
# lor
# or v
# r va
#  var
# vari
# aria
# rian
# iant
# ants
# nts
# ts s
# s so
#  so
# so t
# o th
#  the
# ther
# here
# ere
# re i
# e is
#  is
# is a
# s a
#  a y
# a y
#  y c
# y ch
#  cha
# chan
# hanc
# ance
# nce
# ce t
# e th
#  tha
# that
# hat
# at u
# t un
#  und
# undi
# ndis
# disc
# isco
# scov
# cove
# over
# vere
# ered
# red
# ed b
# d bl
#  bla
# blac
# lack
# ack
# ck s
# k sw
#  swa
# swan
# wans
# ans
# ns e
# s ex
#  exi
# exis
# xist
# ist.
# st.m
# t.ma
# .mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng p
# g pr
#  pro
# prog
# rogr
# ogra
# gram
# rams
# ams
# ms c
# s ca
#  can
# can
# an p
# n pe
#  per
# perf
# erfo
# rfor
# form
# orm
# rm t
# m ta
#  tas
# task
# asks
# sks
# ks w
# s wi
#  wit
# with
# itho
# thou
# hout
# out
# ut b
# t be
#  bei
# bein
# eing
# ing
# ng e
# g ex
#  exp
# expl
# xpli
# plic
# lici
# icit
# citl
# itly
# tly
# ly p
# y pr
#  pro
# prog
# rogr
# ogra
# gram
# ramm
# amme
# mmed
# med
# ed t
# d to
#  to
# to d
# o do
#  do
# do s
# o so
#  so.
# so.
# o. i
# . it
#  it
# it i
# t in
#  inv
# invo
# nvol
# volv
# olve
# lves
# ves
# es c
# s co
#  com
# comp
# ompu
# mput
# pute
# uter
# ters
# ers
# rs l
# s le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng f
# g fr
#  fro
# from
# rom
# om d
# m da
#  dat
# data
# ata
# ta p
# a pr
#  pro
# prov
# rovi
# ovid
# vide
# ided
# ded
# ed s
# d so
#  so
# so t
# o th
#  tha
# that
# hat
# at t
# t th
#  the
# they
# hey
# ey c
# y ca
#  car
# carr
# arry
# rry
# ry o
# y ou
#  out
# out
# ut c
# t ce
#  cer
# cert
# erta
# rtai
# tain
# ain
# in t
# n ta
#  tas
# task
# asks
# sks.
# ks.
# s. f
# . fo
#  for
# for
# or s
# r si
#  sim
# simp
# impl
# mple
# ple
# le t
# e ta
#  tas
# task
# asks
# sks
# ks a
# s as
#  ass
# assi
# ssig
# sign
# igne
# gned
# ned
# ed t
# d to
#  to
# to c
# o co
#  com
# comp
# ompu
# mput
# pute
# uter
# ters
# ers
# rs i
# s it
#  it
# it i
# t is
#  is
# is p
# s po
#  pos
# poss
# ossi
# ssib
# sibl
# ible
# ble
# le t
# e to
#  to
# to p
# o pr
#  pro
# prog
# rogr
# ogra
# gram
# ram
# am a
# m al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms t
# s te
#  tel
# tell
# elli
# llin
# ling
# ing
# ng t
# g th
#  the
# the
# he m
# e ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne h
# e ho
#  how
# how
# ow t
# w to
#  to
# to e
# o ex
#  exe
# exec
# xecu
# ecut
# cute
# ute
# te a
# e al
#  all
# all
# ll s
# l st
#  ste
# step
# teps
# eps
# ps r
# s re
#  req
# requ
# equi
# quir
# uire
# ired
# red
# ed t
# d to
#  to
# to s
# o so
#  sol
# solv
# olve
# lve
# ve t
# e th
#  the
# the
# he p
# e pr
#  pro
# prob
# robl
# oble
# blem
# lem
# em a
# m at
#  at
# at h
# t ha
#  han
# hand
# and
# nd o
# d on
#  on
# on t
# n th
#  the
# the
# he c
# e co
#  com
# comp
# ompu
# mput
# pute
# uter
# ters
# ers
# rs p
# s pa
#  par
# part
# art
# rt n
# t no
#  no
# no l
# o le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng i
# g is
#  is
# is n
# s ne
#  nee
# need
# eede
# eded
# ded.
# ed.
# d. f
# . fo
#  for
# for
# or m
# r mo
#  mor
# more
# ore
# re a
# e ad
#  adv
# adva
# dvan
# vanc
# ance
# nced
# ced
# ed t
# d ta
#  tas
# task
# asks
# sks
# ks i
# s it
#  it
# it c
# t ca
#  can
# can
# an b
# n be
#  be
# be c
# e ch
#  cha
# chal
# hall
# alle
# llen
# leng
# engi
# ngin
# ging
# ing
# ng f
# g fo
#  for
# for
# or a
# r a
#  a h
# a hu
#  hum
# huma
# uman
# man
# an t
# n to
#  to
# to m
# o ma
#  man
# manu
# anua
# nual
# uall
# ally
# lly
# ly c
# y cr
#  cre
# crea
# reat
# eate
# ate
# te t
# e th
#  the
# the
# he n
# e ne
#  nee
# need
# eede
# eded
# ded
# ed a
# d al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms.
# ms.
# s. i
# . in
#  in
# in p
# n pr
#  pra
# prac
# ract
# acti
# ctic
# tice
# ice
# ce i
# e it
#  it
# it c
# t ca
#  can
# can
# an t
# n tu
#  tur
# turn
# urn
# rn o
# n ou
#  out
# out
# ut t
# t to
#  to
# to b
# o be
#  be
# be m
# e mo
#  mor
# more
# ore
# re e
# e ef
#  eff
# effe
# ffec
# fect
# ecti
# ctiv
# tive
# ive
# ve t
# e to
#  to
# to h
# o he
#  hel
# help
# elp
# lp t
# p th
#  the
# the
# he m
# e ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne d
# e de
#  dev
# deve
# evel
# velo
# elop
# lop
# op i
# p it
#  its
# its
# ts o
# s ow
#  own
# own
# wn a
# n al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thm
# hm r
# m ra
#  rat
# rath
# athe
# ther
# her
# er t
# r th
#  tha
# than
# han
# an h
# n ha
#  hav
# havi
# avin
# ving
# ing
# ng h
# g hu
#  hum
# huma
# uman
# man
# an p
# n pr
#  pro
# prog
# rogr
# ogra
# gram
# ramm
# amme
# mmer
# mers
# ers
# rs s
# s sp
#  spe
# spec
# peci
# ecif
# cify
# ify
# fy e
# y ev
#  eve
# ever
# very
# ery
# ry n
# y ne
#  nee
# need
# eede
# eded
# ded
# ed s
# d st
#  ste
# step
# tep.
# ep.t
# p.th
# .the
# the
# he d
# e di
#  dis
# disc
# isci
# scip
# cipl
# ipli
# plin
# line
# ine
# ne o
# e of
#  of
# of m
# f ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng e
# g em
#  emp
# empl
# mplo
# ploy
# loys
# oys
# ys v
# s va
#  var
# vari
# ario
# riou
# ious
# ous
# us a
# s ap
#  app
# appr
# ppro
# proa
# roac
# oach
# ache
# ches
# hes
# es t
# s to
#  to
# to t
# o te
#  tea
# teac
# each
# ach
# ch c
# h co
#  com
# comp
# ompu
# mput
# pute
# uter
# ters
# ers
# rs t
# s to
#  to
# to a
# o ac
#  acc
# acco
# ccom
# comp
# ompl
# mpli
# plis
# lish
# ish
# sh t
# h ta
#  tas
# task
# asks
# sks
# ks w
# s wh
#  whe
# wher
# here
# ere
# re n
# e no
#  no
# no f
# o fu
#  ful
# full
# ully
# lly
# ly s
# y sa
#  sat
# sati
# atis
# tisf
# isfa
# sfac
# fact
# acto
# ctor
# tory
# ory
# ry a
# y al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thm
# hm i
# m is
#  is
# is a
# s av
#  ava
# avai
# vail
# aila
# ilab
# labl
# able
# ble.
# le.
# e. i
# . in
#  in
# in c
# n ca
#  cas
# case
# ases
# ses
# es w
# s wh
#  whe
# wher
# here
# ere
# re v
# e va
#  vas
# vast
# ast
# st n
# t nu
#  num
# numb
# umbe
# mber
# bers
# ers
# rs o
# s of
#  of
# of p
# f po
#  pot
# pote
# oten
# tent
# enti
# ntia
# tial
# ial
# al a
# l an
#  ans
# answ
# nswe
# swer
# wers
# ers
# rs e
# s ex
#  exi
# exis
# xist
# ist
# st o
# t on
#  one
# one
# ne a
# e ap
#  app
# appr
# ppro
# proa
# roac
# oach
# ach
# ch i
# h is
#  is
# is t
# s to
#  to
# to l
# o la
#  lab
# labe
# abel
# bel
# el s
# l so
#  som
# some
# ome
# me o
# e of
#  of
# of t
# f th
#  the
# the
# he c
# e co
#  cor
# corr
# orre
# rrec
# rect
# ect
# ct a
# t an
#  ans
# answ
# nswe
# swer
# wers
# ers
# rs a
# s as
#  as
# as v
# s va
#  val
# vali
# alid
# lid.
# id.
# d. t
# . th
#  thi
# this
# his
# is c
# s ca
#  can
# can
# an t
# n th
#  the
# then
# hen
# en b
# n be
#  be
# be u
# e us
#  use
# used
# sed
# ed a
# d as
#  as
# as t
# s tr
#  tra
# trai
# rain
# aini
# inin
# ning
# ing
# ng d
# g da
#  dat
# data
# ata
# ta f
# a fo
#  for
# for
# or t
# r th
#  the
# the
# he c
# e co
#  com
# comp
# ompu
# mput
# pute
# uter
# ter
# er t
# r to
#  to
# to i
# o im
#  imp
# impr
# mpro
# prov
# rove
# ove
# ve t
# e th
#  the
# the
# he a
# e al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms i
# s it
#  it
# it u
# t us
#  use
# uses
# ses
# es t
# s to
#  to
# to d
# o de
#  det
# dete
# eter
# term
# ermi
# rmin
# mine
# ine
# ne c
# e co
#  cor
# corr
# orre
# rrec
# rect
# ect
# ct a
# t an
#  ans
# answ
# nswe
# swer
# wers
# ers.
# rs.
# s. f
# . fo
#  for
# for
# or e
# r ex
#  exa
# exam
# xamp
# ampl
# mple
# ple
# le t
# e to
#  to
# to t
# o tr
#  tra
# trai
# rain
# ain
# in a
# n a
#  a s
# a sy
#  sys
# syst
# yste
# stem
# tem
# em f
# m fo
#  for
# for
# or t
# r th
#  the
# the
# he t
# e ta
#  tas
# task
# ask
# sk o
# k of
#  of
# of d
# f di
#  dig
# digi
# igit
# gita
# ital
# tal
# al c
# l ch
#  cha
# char
# hara
# arac
# ract
# acte
# cter
# ter
# er r
# r re
#  rec
# reco
# ecog
# cogn
# ogni
# gnit
# niti
# itio
# tion
# ion
# on t
# n th
#  the
# the
# he m
# e mn
#  mni
# mnis
# nist
# ist
# st d
# t da
#  dat
# data
# atas
# tase
# aset
# set
# et o
# t of
#  of
# of h
# f ha
#  han
# hand
# andw
# ndwr
# dwri
# writ
# ritt
# itte
# tten
# ten
# en d
# n di
#  dig
# digi
# igit
# gits
# its
# ts h
# s ha
#  has
# has
# as o
# s of
#  oft
# ofte
# ften
# ten
# en b
# n be
#  bee
# been
# een
# en u
# n us
#  use
# used
# sed.
# ed.t
# d.th
# .the
# the
# he t
# e te
#  ter
# term
# erm
# rm m
# m ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng w
# g wa
#  was
# was
# as c
# s co
#  coi
# coin
# oine
# ined
# ned
# ed i
# d in
#  in
# in
# n  b
#   by
#  by
# by a
# y ar
#  art
# arth
# rthu
# thur
# hur
# ur s
# r sa
#  sam
# samu
# amue
# muel
# uel
# el a
# l an
#  an
# an i
# n ib
#  ibm
# ibm
# bm e
# m em
#  emp
# empl
# mplo
# ploy
# loye
# oyee
# yee
# ee a
# e an
#  and
# and
# nd p
# d pi
#  pio
# pion
# ione
# onee
# neer
# eer
# er i
# r in
#  in
# in t
# n th
#  the
# the
# he f
# e fi
#  fie
# fiel
# ield
# eld
# ld o
# d of
#  of
# of c
# f co
#  com
# comp
# ompu
# mput
# pute
# uter
# ter
# er g
# r ga
#  gam
# gami
# amin
# ming
# ing
# ng a
# g an
#  and
# and
# nd a
# d ar
#  art
# arti
# rtif
# tifi
# ific
# fici
# icia
# cial
# ial
# al i
# l in
#  int
# inte
# ntel
# tell
# elli
# llig
# lige
# igen
# genc
# ence
# nce.
# ce.
# e. a
# . al
#  als
# also
# lso
# so t
# o th
#  the
# the
# he s
# e sy
#  syn
# syno
# ynon
# nony
# onym
# nym
# ym s
# m se
#  sel
# self
# elft
# lfte
# ftea
# teac
# each
# achi
# chin
# hing
# ing
# ng c
# g co
#  com
# comp
# ompu
# mput
# pute
# uter
# ters
# ers
# rs w
# s we
#  wer
# were
# ere
# re u
# e us
#  use
# used
# sed
# ed i
# d in
#  in
# in t
# n th
#  thi
# this
# his
# is t
# s ti
#  tim
# time
# ime
# me p
# e pe
#  per
# peri
# erio
# riod
# iod.
# od.b
# d.by
# .by
# by t
# y th
#  the
# the
# he e
# e ea
#  ear
# earl
# arly
# rly
# ly s
# y s
#  s a
# s an
#  an
# an e
# n ex
#  exp
# expe
# xper
# peri
# erim
# rime
# imen
# ment
# enta
# ntal
# tal
# al l
# l le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng m
# g ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne w
# e wi
#  wit
# with
# ith
# th p
# h pu
#  pun
# punc
# unch
# nche
# ched
# hed
# ed t
# d ta
#  tap
# tape
# ape
# pe m
# e me
#  mem
# memo
# emor
# mory
# ory
# ry c
# y ca
#  cal
# call
# alle
# lled
# led
# ed c
# d cy
#  cyb
# cybe
# yber
# bert
# ertr
# rtro
# tron
# ron
# on h
# n ha
#  had
# had
# ad b
# d be
#  bee
# been
# een
# en d
# n de
#  dev
# deve
# evel
# velo
# elop
# lope
# oped
# ped
# ed b
# d by
#  by
# by r
# y ra
#  ray
# rayt
# ayth
# ythe
# theo
# heon
# eon
# on c
# n co
#  com
# comp
# ompa
# mpan
# pany
# any
# ny t
# y to
#  to
# to a
# o an
#  ana
# anal
# naly
# alyz
# lyze
# yze
# ze s
# e so
#  son
# sona
# onar
# nar
# ar s
# r si
#  sig
# sign
# igna
# gnal
# nals
# als
# ls e
# s el
#  ele
# elec
# lect
# ectr
# ctro
# troc
# roca
# ocar
# card
# ardi
# rdio
# diog
# iogr
# ogra
# gram
# rams
# ams
# ms a
# s an
#  and
# and
# nd s
# d sp
#  spe
# spee
# peec
# eech
# ech
# ch p
# h pa
#  pat
# patt
# atte
# tter
# tern
# erns
# rns
# ns u
# s us
#  usi
# usin
# sing
# ing
# ng r
# g ru
#  rud
# rudi
# udim
# dime
# imen
# ment
# enta
# ntar
# tary
# ary
# ry r
# y re
#  rei
# rein
# einf
# info
# nfor
# forc
# orce
# rcem
# ceme
# emen
# ment
# ent
# nt l
# t le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing.
# ng.
# g. i
# . it
#  it
# it w
# t wa
#  was
# was
# as r
# s re
#  rep
# repe
# epet
# peti
# etit
# titi
# itiv
# tive
# ivel
# vely
# ely
# ly t
# y tr
#  tra
# trai
# rain
# aine
# ined
# ned
# ed b
# d by
#  by
# by a
# y a
#  a h
# a hu
#  hum
# huma
# uman
# man
# an o
# n op
#  ope
# oper
# pera
# erat
# rato
# ator
# tort
# orte
# rtea
# teac
# each
# ache
# cher
# her
# er t
# r to
#  to
# to r
# o re
#  rec
# reco
# ecog
# cogn
# ogni
# gniz
# nize
# ize
# ze p
# e pa
#  pat
# patt
# atte
# tter
# tern
# erns
# rns
# ns a
# s an
#  and
# and
# nd e
# d eq
#  equ
# equi
# quip
# uipp
# ippe
# pped
# ped
# ed w
# d wi
#  wit
# with
# ith
# th a
# h a
#  a g
# a go
#  goo
# goof
# oof
# of b
# f bu
#  but
# butt
# utto
# tton
# ton
# on t
# n to
#  to
# to c
# o ca
#  cau
# caus
# ause
# use
# se i
# e it
#  it
# it t
# t to
#  to
# to r
# o re
#  ree
# reev
# eeva
# eval
# valu
# alua
# luat
# uate
# ate
# te i
# e in
#  inc
# inco
# ncor
# corr
# orre
# rrec
# rect
# ect
# ct d
# t de
#  dec
# deci
# ecis
# cisi
# isio
# sion
# ions
# ons.
# ns.
# s. a
# . a
#  a r
# a re
#  rep
# repr
# epre
# pres
# rese
# esen
# sent
# enta
# ntat
# tati
# ativ
# tive
# ive
# ve b
# e bo
#  boo
# book
# ook
# ok o
# k on
#  on
# on r
# n re
#  res
# rese
# esea
# sear
# earc
# arch
# rch
# ch i
# h in
#  int
# into
# nto
# to m
# o ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng d
# g du
#  dur
# duri
# urin
# ring
# ing
# ng t
# g th
#  the
# the
# he s
# e s
#  s w
# s wa
#  was
# was
# as n
# s ni
#  nil
# nils
# ilss
# lsso
# sson
# sons
# ons
# ns b
# s bo
#  boo
# book
# ook
# ok o
# k on
#  on
# on l
# n le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng m
# g ma
#  mac
# mach
# achi
# chin
# hine
# ines
# nes
# es d
# s de
#  dea
# deal
# eali
# alin
# ling
# ing
# ng m
# g mo
#  mos
# most
# ostl
# stly
# tly
# ly w
# y wi
#  wit
# with
# ith
# th m
# h ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng f
# g fo
#  for
# for
# or p
# r pa
#  pat
# patt
# atte
# tter
# tern
# ern
# rn c
# n cl
#  cla
# clas
# lass
# assi
# ssif
# sifi
# ific
# fica
# icat
# cati
# atio
# tion
# ion.
# on.
# n. i
# . in
#  int
# inte
# nter
# tere
# eres
# rest
# est
# st r
# t re
#  rel
# rela
# elat
# late
# ated
# ted
# ed t
# d to
#  to
# to p
# o pa
#  pat
# patt
# atte
# tter
# tern
# ern
# rn r
# n re
#  rec
# reco
# ecog
# cogn
# ogni
# gnit
# niti
# itio
# tion
# ion
# on c
# n co
#  con
# cont
# onti
# ntin
# tinu
# inue
# nued
# ued
# ed i
# d in
#  int
# into
# nto
# to t
# o th
#  the
# the
# he s
# e s
#  s a
# s as
#  as
# as d
# s de
#  des
# desc
# escr
# scri
# crib
# ribe
# ibed
# bed
# ed b
# d by
#  by
# by d
# y du
#  dud
# duda
# uda
# da a
# a an
#  and
# and
# nd h
# d ha
#  har
# hart
# art
# rt i
# t in
#  in
# in .
# n .
#  . i
# . in
#  in
# in
# n  a
#   a
#  a r
# a re
#  rep
# repo
# epor
# port
# ort
# rt w
# t wa
#  was
# was
# as g
# s gi
#  giv
# give
# iven
# ven
# en o
# n on
#  on
# on u
# n us
#  usi
# usin
# sing
# ing
# ng t
# g te
#  tea
# teac
# each
# achi
# chin
# hing
# ing
# ng s
# g st
#  str
# stra
# trat
# rate
# ateg
# tegi
# egie
# gies
# ies
# es s
# s so
#  so
# so t
# o th
#  tha
# that
# hat
# at a
# t a
#  a n
# a ne
#  neu
# neur
# eura
# ural
# ral
# al n
# l ne
#  net
# netw
# etwo
# twor
# work
# ork
# rk l
# k le
#  lea
# lear
# earn
# arns
# rns
# ns t
# s to
#  to
# to r
# o re
#  rec
# reco
# ecog
# cogn
# ogni
# gniz
# nize
# ize
# ze
# e  c
#   ch
#  cha
# char
# hara
# arac
# ract
# acte
# cter
# ters
# ers
# rs
# s  l
#   le
#  let
# lett
# ette
# tter
# ters
# ers
# rs
# s  d
#   di
#  dig
# digi
# igit
# gits
# its
# ts a
# s an
#  and
# and
# nd
# d  s
#   sp
#  spe
# spec
# peci
# ecia
# cial
# ial
# al s
# l sy
#  sym
# symb
# ymbo
# mbol
# bols
# ols
# ls f
# s fr
#  fro
# from
# rom
# om a
# m a
#  a c
# a co
#  com
# comp
# ompu
# mput
# pute
# uter
# ter
# er t
# r te
#  ter
# term
# ermi
# rmin
# mina
# inal
# nal.
# al.t
# l.to
# .tom
# tom
# om m
# m m.
#  m.
# m. m
# . mi
#  mit
# mitc
# itch
# tche
# chel
# hell
# ell
# ll p
# l pr
#  pro
# prov
# rovi
# ovid
# vide
# ided
# ded
# ed a
# d a
#  a w
# a wi
#  wid
# wide
# idel
# dely
# ely
# ly q
# y qu
#  quo
# quot
# uote
# oted
# ted
# ed m
# d mo
#  mor
# more
# ore
# re f
# e fo
#  for
# form
# orma
# rmal
# mal
# al d
# l de
#  def
# defi
# efin
# fini
# init
# niti
# itio
# tion
# ion
# on o
# n of
#  of
# of t
# f th
#  the
# the
# he a
# e al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms s
# s st
#  stu
# stud
# tudi
# udie
# died
# ied
# ed i
# d in
#  in
# in t
# n th
#  the
# the
# he m
# e ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng f
# g fi
#  fie
# fiel
# ield
# eld
# ld a
# d a
#  a c
# a co
#  com
# comp
# ompu
# mput
# pute
# uter
# ter
# er p
# r pr
#  pro
# prog
# rogr
# ogra
# gram
# ram
# am i
# m is
#  is
# is s
# s sa
#  sai
# said
# aid
# id t
# d to
#  to
# to l
# o le
#  lea
# lear
# earn
# arn
# rn f
# n fr
#  fro
# from
# rom
# om e
# m ex
#  exp
# expe
# xper
# peri
# erie
# rien
# ienc
# ence
# nce
# ce e
# e e
#  e w
# e wi
#  wit
# with
# ith
# th r
# h re
#  res
# resp
# espe
# spec
# pect
# ect
# ct t
# t to
#  to
# to s
# o so
#  som
# some
# ome
# me c
# e cl
#  cla
# clas
# lass
# ass
# ss o
# s of
#  of
# of t
# f ta
#  tas
# task
# asks
# sks
# ks t
# s t
#  t a
# t an
#  and
# and
# nd p
# d pe
#  per
# perf
# erfo
# rfor
# form
# orma
# rman
# manc
# ance
# nce
# ce m
# e me
#  mea
# meas
# easu
# asur
# sure
# ure
# re p
# e p
#  p i
# p if
#  if
# if i
# f it
#  its
# its
# ts p
# s pe
#  per
# perf
# erfo
# rfor
# form
# orma
# rman
# manc
# ance
# nce
# ce a
# e at
#  at
# at t
# t ta
#  tas
# task
# asks
# sks
# ks i
# s in
#  in
# in t
# n t
#  t a
# t as
#  as
# as m
# s me
#  mea
# meas
# easu
# asur
# sure
# ured
# red
# ed b
# d by
#  by
# by p
# y p
#  p
# p  i
#   im
#  imp
# impr
# mpro
# prov
# rove
# oves
# ves
# es w
# s wi
#  wit
# with
# ith
# th e
# h ex
#  exp
# expe
# xper
# peri
# erie
# rien
# ienc
# ence
# nce
# ce e
# e e.
#  e.
# e. t
# . th
#  thi
# this
# his
# is d
# s de
#  def
# defi
# efin
# fini
# init
# niti
# itio
# tion
# ion
# on o
# n of
#  of
# of t
# f th
#  the
# the
# he t
# e ta
#  tas
# task
# asks
# sks
# ks i
# s in
#  in
# in w
# n wh
#  whi
# whic
# hich
# ich
# ch m
# h ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng i
# g is
#  is
# is c
# s co
#  con
# conc
# once
# ncer
# cern
# erne
# rned
# ned
# ed o
# d of
#  off
# offe
# ffer
# fers
# ers
# rs a
# s a
#  a f
# a fu
#  fun
# fund
# unda
# ndam
# dame
# amen
# ment
# enta
# ntal
# tall
# ally
# lly
# ly o
# y op
#  ope
# oper
# pera
# erat
# rati
# atio
# tion
# iona
# onal
# nal
# al d
# l de
#  def
# defi
# efin
# fini
# init
# niti
# itio
# tion
# ion
# on r
# n ra
#  rat
# rath
# athe
# ther
# her
# er t
# r th
#  tha
# than
# han
# an d
# n de
#  def
# defi
# efin
# fini
# inin
# ning
# ing
# ng t
# g th
#  the
# the
# he f
# e fi
#  fie
# fiel
# ield
# eld
# ld i
# d in
#  in
# in c
# n co
#  cog
# cogn
# ogni
# gnit
# niti
# itiv
# tive
# ive
# ve t
# e te
#  ter
# term
# erms
# rms.
# ms.
# s. t
# . th
#  thi
# this
# his
# is f
# s fo
#  fol
# foll
# ollo
# llow
# lows
# ows
# ws a
# s al
#  ala
# alan
# lan
# an t
# n tu
#  tur
# turi
# urin
# ring
# ings
# ngs
# gs p
# s pr
#  pro
# prop
# ropo
# opos
# posa
# osal
# sal
# al i
# l in
#  in
# in h
# n hi
#  his
# his
# is p
# s pa
#  pap
# pape
# aper
# per
# er c
# r co
#  com
# comp
# ompu
# mput
# puti
# utin
# ting
# ing
# ng m
# g ma
#  mac
# mach
# achi
# chin
# hine
# iner
# nery
# ery
# ry a
# y an
#  and
# and
# nd i
# d in
#  int
# inte
# ntel
# tell
# elli
# llig
# lige
# igen
# genc
# ence
# nce
# ce i
# e in
#  in
# in w
# n wh
#  whi
# whic
# hich
# ich
# ch t
# h th
#  the
# the
# he q
# e qu
#  que
# ques
# uest
# esti
# stio
# tion
# ion
# on c
# n ca
#  can
# can
# an m
# n ma
#  mac
# mach
# achi
# chin
# hine
# ines
# nes
# es t
# s th
#  thi
# thin
# hink
# ink
# nk i
# k is
#  is
# is r
# s re
#  rep
# repl
# epla
# plac
# lace
# aced
# ced
# ed w
# d wi
#  wit
# with
# ith
# th t
# h th
#  the
# the
# he q
# e qu
#  que
# ques
# uest
# esti
# stio
# tion
# ion
# on c
# n ca
#  can
# can
# an m
# n ma
#  mac
# mach
# achi
# chin
# hine
# ines
# nes
# es d
# s do
#  do
# do w
# o wh
#  wha
# what
# hat
# at w
# t we
#  we
# we a
# e as
#  as
# as t
# s th
#  thi
# thin
# hink
# inki
# nkin
# king
# ing
# ng e
# g en
#  ent
# enti
# ntit
# titi
# itie
# ties
# ies
# es c
# s ca
#  can
# can
# an d
# n do
#  do.
# do.m
# o.mo
# .mod
# mode
# oder
# dern
# ern
# rn d
# n da
#  day
# day
# ay m
# y ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng h
# g ha
#  has
# has
# as t
# s tw
#  two
# two
# wo o
# o ob
#  obj
# obje
# bjec
# ject
# ecti
# ctiv
# tive
# ives
# ves
# es o
# s on
#  one
# one
# ne i
# e is
#  is
# is t
# s to
#  to
# to c
# o cl
#  cla
# clas
# lass
# assi
# ssif
# sify
# ify
# fy d
# y da
#  dat
# data
# ata
# ta b
# a ba
#  bas
# base
# ased
# sed
# ed o
# d on
#  on
# on m
# n mo
#  mod
# mode
# odel
# dels
# els
# ls w
# s wh
#  whi
# whic
# hich
# ich
# ch h
# h ha
#  hav
# have
# ave
# ve b
# e be
#  bee
# been
# een
# en d
# n de
#  dev
# deve
# evel
# velo
# elop
# lope
# oped
# ped
# ed t
# d th
#  the
# the
# he o
# e ot
#  oth
# othe
# ther
# her
# er p
# r pu
#  pur
# purp
# urpo
# rpos
# pose
# ose
# se i
# e is
#  is
# is t
# s to
#  to
# to m
# o ma
#  mak
# make
# ake
# ke p
# e pr
#  pre
# pred
# redi
# edic
# dict
# icti
# ctio
# tion
# ions
# ons
# ns f
# s fo
#  for
# for
# or f
# r fu
#  fut
# futu
# utur
# ture
# ure
# re o
# e ou
#  out
# outc
# utco
# tcom
# come
# omes
# mes
# es b
# s ba
#  bas
# base
# ased
# sed
# ed o
# d on
#  on
# on t
# n th
#  the
# thes
# hese
# ese
# se m
# e mo
#  mod
# mode
# odel
# dels
# els.
# ls.
# s. a
# . a
#  a h
# a hy
#  hyp
# hypo
# ypot
# poth
# othe
# thet
# heti
# etic
# tica
# ical
# cal
# al a
# l al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thm
# hm s
# m sp
#  spe
# spec
# peci
# ecif
# cifi
# ific
# fic
# ic t
# c to
#  to
# to c
# o cl
#  cla
# clas
# lass
# assi
# ssif
# sify
# ifyi
# fyin
# ying
# ing
# ng d
# g da
#  dat
# data
# ata
# ta m
# a ma
#  may
# may
# ay u
# y us
#  use
# use
# se c
# e co
#  com
# comp
# ompu
# mput
# pute
# uter
# ter
# er v
# r vi
#  vis
# visi
# isio
# sion
# ion
# on o
# n of
#  of
# of m
# f mo
#  mol
# mole
# oles
# les
# es c
# s co
#  cou
# coup
# oupl
# uple
# pled
# led
# ed w
# d wi
#  wit
# with
# ith
# th s
# h su
#  sup
# supe
# uper
# perv
# ervi
# rvis
# vise
# ised
# sed
# ed l
# d le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng i
# g in
#  in
# in o
# n or
#  ord
# orde
# rder
# der
# er t
# r to
#  to
# to t
# o tr
#  tra
# trai
# rain
# ain
# in i
# n it
#  it
# it t
# t to
#  to
# to c
# o cl
#  cla
# clas
# lass
# assi
# ssif
# sify
# ify
# fy t
# y th
#  the
# the
# he c
# e ca
#  can
# canc
# ance
# ncer
# cero
# erou
# rous
# ous
# us m
# s mo
#  mol
# mole
# oles
# les.
# es.
# s. a
# . a
#  a m
# a ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thm
# hm f
# m fo
#  for
# for
# or s
# r st
#  sto
# stoc
# tock
# ock
# ck t
# k tr
#  tra
# trad
# radi
# adin
# ding
# ing
# ng m
# g ma
#  may
# may
# ay i
# y in
#  inf
# info
# nfor
# form
# orm
# rm t
# m th
#  the
# the
# he t
# e tr
#  tra
# trad
# rade
# ader
# der
# er o
# r of
#  of
# of f
# f fu
#  fut
# futu
# utur
# ture
# ure
# re p
# e po
#  pot
# pote
# oten
# tent
# enti
# ntia
# tial
# ial
# al p
# l pr
#  pre
# pred
# redi
# edic
# dict
# icti
# ctio
# tion
# ions
# ons.
# ns.a
# s.as
# .as
# as a
# s a
#  a s
# a sc
#  sci
# scie
# cien
# ient
# enti
# ntif
# tifi
# ific
# fic
# ic e
# c en
#  end
# ende
# ndea
# deav
# eavo
# avor
# vor
# or m
# r ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng g
# g gr
#  gre
# grew
# rew
# ew o
# w ou
#  out
# out
# ut o
# t of
#  of
# of t
# f th
#  the
# the
# he q
# e qu
#  que
# ques
# uest
# est
# st f
# t fo
#  for
# for
# or a
# r ar
#  art
# arti
# rtif
# tifi
# ific
# fici
# icia
# cial
# ial
# al i
# l in
#  int
# inte
# ntel
# tell
# elli
# llig
# lige
# igen
# genc
# ence
# nce.
# ce.
# e. i
# . in
#  in
# in t
# n th
#  the
# the
# he e
# e ea
#  ear
# earl
# arly
# rly
# ly d
# y da
#  day
# days
# ays
# ys o
# s of
#  of
# of a
# f ai
#  ai
# ai a
# i as
#  as
# as a
# s an
#  an
# an a
# n ac
#  aca
# acad
# cade
# adem
# demi
# emic
# mic
# ic d
# c di
#  dis
# disc
# isci
# scip
# cipl
# ipli
# plin
# line
# ine
# ne s
# e so
#  som
# some
# ome
# me r
# e re
#  res
# rese
# esea
# sear
# earc
# arch
# rche
# cher
# hers
# ers
# rs w
# s we
#  wer
# were
# ere
# re i
# e in
#  int
# inte
# nter
# tere
# eres
# rest
# este
# sted
# ted
# ed i
# d in
#  in
# in h
# n ha
#  hav
# havi
# avin
# ving
# ing
# ng m
# g ma
#  mac
# mach
# achi
# chin
# hine
# ines
# nes
# es l
# s le
#  lea
# lear
# earn
# arn
# rn f
# n fr
#  fro
# from
# rom
# om d
# m da
#  dat
# data
# ata.
# ta.
# a. t
# . th
#  the
# they
# hey
# ey a
# y at
#  att
# atte
# ttem
# temp
# empt
# mpte
# pted
# ted
# ed t
# d to
#  to
# to a
# o ap
#  app
# appr
# ppro
# proa
# roac
# oach
# ach
# ch t
# h th
#  the
# the
# he p
# e pr
#  pro
# prob
# robl
# oble
# blem
# lem
# em w
# m wi
#  wit
# with
# ith
# th v
# h va
#  var
# vari
# ario
# riou
# ious
# ous
# us s
# s sy
#  sym
# symb
# ymbo
# mbol
# boli
# olic
# lic
# ic m
# c me
#  met
# meth
# etho
# thod
# hods
# ods
# ds a
# s as
#  as
# as w
# s we
#  wel
# well
# ell
# ll a
# l as
#  as
# as w
# s wh
#  wha
# what
# hat
# at w
# t wa
#  was
# was
# as t
# s th
#  the
# then
# hen
# en t
# n te
#  ter
# term
# erme
# rmed
# med
# ed n
# d ne
#  neu
# neur
# eura
# ural
# ral
# al n
# l ne
#  net
# netw
# etwo
# twor
# work
# orks
# rks
# ks t
# s th
#  the
# thes
# hese
# ese
# se w
# e we
#  wer
# were
# ere
# re m
# e mo
#  mos
# most
# ostl
# stly
# tly
# ly p
# y pe
#  per
# perc
# erce
# rcep
# cept
# eptr
# ptro
# tron
# rons
# ons
# ns a
# s an
#  and
# and
# nd o
# d ot
#  oth
# othe
# ther
# her
# er m
# r mo
#  mod
# mode
# odel
# dels
# els
# ls t
# s th
#  tha
# that
# hat
# at w
# t we
#  wer
# were
# ere
# re l
# e la
#  lat
# late
# ater
# ter
# er f
# r fo
#  fou
# foun
# ound
# und
# nd t
# d to
#  to
# to b
# o be
#  be
# be r
# e re
#  rei
# rein
# einv
# inve
# nven
# vent
# enti
# ntio
# tion
# ions
# ons
# ns o
# s of
#  of
# of t
# f th
#  the
# the
# he g
# e ge
#  gen
# gene
# ener
# nera
# eral
# rali
# aliz
# lize
# ized
# zed
# ed l
# d li
#  lin
# line
# inea
# near
# ear
# ar m
# r mo
#  mod
# mode
# odel
# dels
# els
# ls o
# s of
#  of
# of s
# f st
#  sta
# stat
# tati
# atis
# tist
# isti
# stic
# tics
# ics.
# cs.
# s. p
# . pr
#  pro
# prob
# roba
# obab
# babi
# abil
# bili
# ilis
# list
# isti
# stic
# tic
# ic r
# c re
#  rea
# reas
# easo
# ason
# soni
# onin
# ning
# ing
# ng w
# g wa
#  was
# was
# as a
# s al
#  als
# also
# lso
# so e
# o em
#  emp
# empl
# mplo
# ploy
# loye
# oyed
# yed
# ed e
# d es
#  esp
# espe
# spec
# peci
# ecia
# cial
# iall
# ally
# lly
# ly i
# y in
#  in
# in a
# n au
#  aut
# auto
# utom
# toma
# omat
# mate
# ated
# ted
# ed m
# d me
#  med
# medi
# edic
# dica
# ical
# cal
# al d
# l di
#  dia
# diag
# iagn
# agno
# gnos
# nosi
# osis
# sis.
# is.h
# s.ho
# .how
# howe
# owev
# weve
# ever
# ver
# er a
# r an
#  an
# an i
# n in
#  inc
# incr
# ncre
# crea
# reas
# easi
# asin
# sing
# ing
# ng e
# g em
#  emp
# emph
# mpha
# phas
# hasi
# asis
# sis
# is o
# s on
#  on
# on t
# n th
#  the
# the
# he l
# e lo
#  log
# logi
# ogic
# gica
# ical
# cal
# al k
# l kn
#  kno
# know
# nowl
# owle
# wled
# ledg
# edge
# dgeb
# geba
# ebas
# base
# ased
# sed
# ed a
# d ap
#  app
# appr
# ppro
# proa
# roac
# oach
# ach
# ch c
# h ca
#  cau
# caus
# ause
# used
# sed
# ed a
# d a
#  a r
# a ri
#  rif
# rift
# ift
# ft b
# t be
#  bet
# betw
# etwe
# twee
# ween
# een
# en a
# n ai
#  ai
# ai a
# i an
#  and
# and
# nd m
# d ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing.
# ng.
# g. p
# . pr
#  pro
# prob
# roba
# obab
# babi
# abil
# bili
# ilis
# list
# isti
# stic
# tic
# ic s
# c sy
#  sys
# syst
# yste
# stem
# tems
# ems
# ms w
# s we
#  wer
# were
# ere
# re p
# e pl
#  pla
# plag
# lagu
# ague
# gued
# ued
# ed b
# d by
#  by
# by t
# y th
#  the
# theo
# heor
# eore
# oret
# reti
# etic
# tica
# ical
# cal
# al a
# l an
#  and
# and
# nd p
# d pr
#  pra
# prac
# ract
# acti
# ctic
# tica
# ical
# cal
# al p
# l pr
#  pro
# prob
# robl
# oble
# blem
# lems
# ems
# ms o
# s of
#  of
# of d
# f da
#  dat
# data
# ata
# ta a
# a ac
#  acq
# acqu
# cqui
# quis
# uisi
# isit
# siti
# itio
# tion
# ion
# on a
# n an
#  and
# and
# nd r
# d re
#  rep
# repr
# epre
# pres
# rese
# esen
# sent
# enta
# ntat
# tati
# atio
# tion
# ion.
# on.
# n. b
# . by
#  by
# by
# y  e
#   ex
#  exp
# expe
# xper
# pert
# ert
# rt s
# t sy
#  sys
# syst
# yste
# stem
# tems
# ems
# ms h
# s ha
#  had
# had
# ad c
# d co
#  com
# come
# ome
# me t
# e to
#  to
# to d
# o do
#  dom
# domi
# omin
# mina
# inat
# nate
# ate
# te a
# e ai
#  ai
# ai a
# i an
#  and
# and
# nd s
# d st
#  sta
# stat
# tati
# atis
# tist
# isti
# stic
# tics
# ics
# cs w
# s wa
#  was
# was
# as o
# s ou
#  out
# out
# ut o
# t of
#  of
# of f
# f fa
#  fav
# favo
# avor
# vor.
# or.
# r. w
# . wo
#  wor
# work
# ork
# rk o
# k on
#  on
# on s
# n sy
#  sym
# symb
# ymbo
# mbol
# boli
# olic
# lick
# ickn
# ckno
# know
# nowl
# owle
# wled
# ledg
# edge
# dgeb
# geba
# ebas
# base
# ased
# sed
# ed l
# d le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng d
# g di
#  did
# did
# id c
# d co
#  con
# cont
# onti
# ntin
# tinu
# inue
# nue
# ue w
# e wi
#  wit
# with
# ithi
# thin
# hin
# in a
# n ai
#  ai
# ai l
# i le
#  lea
# lead
# eadi
# adin
# ding
# ing
# ng t
# g to
#  to
# to i
# o in
#  ind
# indu
# nduc
# duct
# ucti
# ctiv
# tive
# ive
# ve l
# e lo
#  log
# logi
# ogic
# gic
# ic p
# c pr
#  pro
# prog
# rogr
# ogra
# gram
# ramm
# ammi
# mmin
# ming
# ing
# ng b
# g bu
#  but
# but
# ut t
# t th
#  the
# the
# he m
# e mo
#  mor
# more
# ore
# re s
# e st
#  sta
# stat
# tati
# atis
# tist
# isti
# stic
# tica
# ical
# cal
# al l
# l li
#  lin
# line
# ine
# ne o
# e of
#  of
# of r
# f re
#  res
# rese
# esea
# sear
# earc
# arch
# rch
# ch w
# h wa
#  was
# was
# as n
# s no
#  now
# now
# ow o
# w ou
#  out
# outs
# utsi
# tsid
# side
# ide
# de t
# e th
#  the
# the
# he f
# e fi
#  fie
# fiel
# ield
# eld
# ld o
# d of
#  of
# of a
# f ai
#  ai
# ai p
# i pr
#  pro
# prop
# rope
# oper
# per
# er i
# r in
#  in
# in p
# n pa
#  pat
# patt
# atte
# tter
# tern
# ern
# rn r
# n re
#  rec
# reco
# ecog
# cogn
# ogni
# gnit
# niti
# itio
# tion
# ion
# on a
# n an
#  and
# and
# nd i
# d in
#  inf
# info
# nfor
# form
# orma
# rmat
# mati
# atio
# tion
# ion
# on r
# n re
#  ret
# retr
# etri
# trie
# riev
# ieva
# eval
# val.
# al.
# l. n
# . ne
#  neu
# neur
# eura
# ural
# ral
# al n
# l ne
#  net
# netw
# etwo
# twor
# work
# orks
# rks
# ks r
# s re
#  res
# rese
# esea
# sear
# earc
# arch
# rch
# ch h
# h ha
#  had
# had
# ad b
# d be
#  bee
# been
# een
# en a
# n ab
#  aba
# aban
# band
# ando
# ndon
# done
# oned
# ned
# ed b
# d by
#  by
# by a
# y ai
#  ai
# ai a
# i an
#  and
# and
# nd c
# d co
#  com
# comp
# ompu
# mput
# pute
# uter
# ter
# er s
# r sc
#  sci
# scie
# cien
# ienc
# ence
# nce
# ce a
# e ar
#  aro
# arou
# roun
# ound
# und
# nd t
# d th
#  the
# the
# he s
# e sa
#  sam
# same
# ame
# me t
# e ti
#  tim
# time
# ime.
# me.
# e. t
# . th
#  thi
# this
# his
# is l
# s li
#  lin
# line
# ine
# ne t
# e to
#  too
# too
# oo w
# o wa
#  was
# was
# as c
# s co
#  con
# cont
# onti
# ntin
# tinu
# inue
# nued
# ued
# ed o
# d ou
#  out
# outs
# utsi
# tsid
# side
# ide
# de t
# e th
#  the
# the
# he a
# e ai
#  aic
# aics
# ics
# cs f
# s fi
#  fie
# fiel
# ield
# eld
# ld a
# d as
#  as
# as c
# s co
#  con
# conn
# onne
# nnec
# nect
# ecti
# ctio
# tion
# ioni
# onis
# nism
# ism
# sm b
# m by
#  by
# by r
# y re
#  res
# rese
# esea
# sear
# earc
# arch
# rche
# cher
# hers
# ers
# rs f
# s fr
#  fro
# from
# rom
# om o
# m ot
#  oth
# othe
# ther
# her
# er d
# r di
#  dis
# disc
# isci
# scip
# cipl
# ipli
# plin
# line
# ines
# nes
# es i
# s in
#  inc
# incl
# nclu
# clud
# ludi
# udin
# ding
# ing
# ng h
# g ho
#  hop
# hopf
# opfi
# pfie
# fiel
# ield
# eld
# ld r
# d ru
#  rum
# rume
# umel
# melh
# elha
# lhar
# hart
# art
# rt a
# t an
#  and
# and
# nd h
# d hi
#  hin
# hint
# into
# nton
# ton.
# on.
# n. t
# . th
#  the
# thei
# heir
# eir
# ir m
# r ma
#  mai
# main
# ain
# in s
# n su
#  suc
# succ
# ucce
# cces
# cess
# ess
# ss c
# s ca
#  cam
# came
# ame
# me i
# e in
#  in
# in t
# n th
#  the
# the
# he m
# e mi
#  mid
# mids
# ids
# ds w
# s wi
#  wit
# with
# ith
# th t
# h th
#  the
# the
# he r
# e re
#  rei
# rein
# einv
# inve
# nven
# vent
# enti
# ntio
# tion
# ion
# on o
# n of
#  of
# of b
# f ba
#  bac
# back
# ackp
# ckpr
# kpro
# prop
# ropa
# opag
# paga
# agat
# gati
# atio
# tion
# ion.
# on.m
# n.ma
# .mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng m
# g ml
#  ml
# ml r
# l re
#  reo
# reor
# eorg
# orga
# rgan
# gani
# aniz
# nize
# ized
# zed
# ed a
# d as
#  as
# as a
# s a
#  a s
# a se
#  sep
# sepa
# epar
# para
# arat
# rate
# ate
# te f
# e fi
#  fie
# fiel
# ield
# eld
# ld s
# d st
#  sta
# star
# tart
# arte
# rted
# ted
# ed t
# d to
#  to
# to f
# o fl
#  flo
# flou
# lour
# ouri
# uris
# rish
# ish
# sh i
# h in
#  in
# in t
# n th
#  the
# the
# he s
# e s.
#  s.
# s. t
# . th
#  the
# the
# he f
# e fi
#  fie
# fiel
# ield
# eld
# ld c
# d ch
#  cha
# chan
# hang
# ange
# nged
# ged
# ed i
# d it
#  its
# its
# ts g
# s go
#  goa
# goal
# oal
# al f
# l fr
#  fro
# from
# rom
# om a
# m ac
#  ach
# achi
# chie
# hiev
# ievi
# evin
# ving
# ing
# ng a
# g ar
#  art
# arti
# rtif
# tifi
# ific
# fici
# icia
# cial
# ial
# al i
# l in
#  int
# inte
# ntel
# tell
# elli
# llig
# lige
# igen
# genc
# ence
# nce
# ce t
# e to
#  to
# to t
# o ta
#  tac
# tack
# ackl
# ckli
# klin
# ling
# ing
# ng s
# g so
#  sol
# solv
# olva
# lvab
# vabl
# able
# ble
# le p
# e pr
#  pro
# prob
# robl
# oble
# blem
# lems
# ems
# ms o
# s of
#  of
# of a
# f a
#  a p
# a pr
#  pra
# prac
# ract
# acti
# ctic
# tica
# ical
# cal
# al n
# l na
#  nat
# natu
# atur
# ture
# ure.
# re.
# e. i
# . it
#  it
# it s
# t sh
#  shi
# shif
# hift
# ifte
# fted
# ted
# ed f
# d fo
#  foc
# focu
# ocus
# cus
# us a
# s aw
#  awa
# away
# way
# ay f
# y fr
#  fro
# from
# rom
# om t
# m th
#  the
# the
# he s
# e sy
#  sym
# symb
# ymbo
# mbol
# boli
# olic
# lic
# ic a
# c ap
#  app
# appr
# ppro
# proa
# roac
# oach
# ache
# ches
# hes
# es i
# s it
#  it
# it h
# t ha
#  had
# had
# ad i
# d in
#  inh
# inhe
# nher
# heri
# erit
# rite
# ited
# ted
# ed f
# d fr
#  fro
# from
# rom
# om a
# m ai
#  ai
# ai a
# i an
#  and
# and
# nd t
# d to
#  tow
# towa
# owar
# ward
# ard
# rd m
# d me
#  met
# meth
# etho
# thod
# hods
# ods
# ds a
# s an
#  and
# and
# nd m
# d mo
#  mod
# mode
# odel
# dels
# els
# ls b
# s bo
#  bor
# borr
# orro
# rrow
# rowe
# owed
# wed
# ed f
# d fr
#  fro
# from
# rom
# om s
# m st
#  sta
# stat
# tati
# atis
# tist
# isti
# stic
# tics
# ics
# cs f
# s fu
#  fuz
# fuzz
# uzzy
# zzy
# zy l
# y lo
#  log
# logi
# ogic
# gic
# ic a
# c an
#  and
# and
# nd p
# d pr
#  pro
# prob
# roba
# obab
# babi
# abil
# bili
# ilit
# lity
# ity
# ty t
# y th
#  the
# theo
# heor
# eory
# ory.
# ry.t
# y.th
# .the
# the
# he d
# e di
#  dif
# diff
# iffe
# ffer
# fere
# eren
# renc
# ence
# nce
# ce b
# e be
#  bet
# betw
# etwe
# twee
# ween
# een
# en m
# n ml
#  ml
# ml a
# l an
#  and
# and
# nd a
# d ai
#  ai
# ai i
# i is
#  is
# is f
# s fr
#  fre
# freq
# requ
# eque
# quen
# uent
# entl
# ntly
# tly
# ly m
# y mi
#  mis
# misu
# isun
# sund
# unde
# nder
# ders
# erst
# rsto
# stoo
# tood
# ood.
# od.
# d. m
# . ml
#  ml
# ml l
# l le
#  lea
# lear
# earn
# arns
# rns
# ns a
# s an
#  and
# and
# nd p
# d pr
#  pre
# pred
# redi
# edic
# dict
# icts
# cts
# ts b
# s ba
#  bas
# base
# ased
# sed
# ed o
# d on
#  on
# on p
# n pa
#  pas
# pass
# assi
# ssiv
# sive
# ive
# ve o
# e ob
#  obs
# obse
# bser
# serv
# erva
# rvat
# vati
# atio
# tion
# ions
# ons
# ns w
# s wh
#  whe
# wher
# here
# erea
# reas
# eas
# as a
# s ai
#  ai
# ai i
# i im
#  imp
# impl
# mpli
# plie
# lies
# ies
# es a
# s an
#  an
# an a
# n ag
#  age
# agen
# gent
# ent
# nt i
# t in
#  int
# inte
# nter
# tera
# erac
# ract
# acti
# ctin
# ting
# ing
# ng w
# g wi
#  wit
# with
# ith
# th t
# h th
#  the
# the
# he e
# e en
#  env
# envi
# nvir
# viro
# iron
# ronm
# onme
# nmen
# ment
# ent
# nt t
# t to
#  to
# to l
# o le
#  lea
# lear
# earn
# arn
# rn a
# n an
#  and
# and
# nd t
# d ta
#  tak
# take
# ake
# ke a
# e ac
#  act
# acti
# ctio
# tion
# ions
# ons
# ns t
# s th
#  tha
# that
# hat
# at m
# t ma
#  max
# maxi
# axim
# ximi
# imiz
# mize
# ize
# ze i
# e it
#  its
# its
# ts c
# s ch
#  cha
# chan
# hanc
# ance
# nce
# ce o
# e of
#  of
# of s
# f su
#  suc
# succ
# ucce
# cces
# cess
# essf
# ssfu
# sful
# full
# ully
# lly
# ly a
# y ac
#  ach
# achi
# chie
# hiev
# ievi
# evin
# ving
# ing
# ng i
# g it
#  its
# its
# ts g
# s go
#  goa
# goal
# oals
# als.
# ls.a
# s.as
# .as
# as o
# s of
#  of
# of
# f  m
#   ma
#  man
# many
# any
# ny s
# y so
#  sou
# sour
# ourc
# urce
# rces
# ces
# es c
# s co
#  con
# cont
# onti
# ntin
# tinu
# inue
# nue
# ue t
# e to
#  to
# to a
# o as
#  ass
# asse
# sser
# sert
# ert
# rt t
# t th
#  tha
# that
# hat
# at m
# t ml
#  ml
# ml r
# l re
#  rem
# rema
# emai
# main
# ains
# ins
# ns a
# s a
#  a s
# a su
#  sub
# subf
# ubfi
# bfie
# fiel
# ield
# eld
# ld o
# d of
#  of
# of a
# f ai
#  ai.
# ai.
# i. o
# . ot
#  oth
# othe
# ther
# hers
# ers
# rs h
# s ha
#  hav
# have
# ave
# ve t
# e th
#  the
# the
# he v
# e vi
#  vie
# view
# iew
# ew t
# w th
#  tha
# that
# hat
# at n
# t no
#  not
# not
# ot a
# t al
#  all
# all
# ll m
# l ml
#  ml
# ml i
# l is
#  is
# is p
# s pa
#  par
# part
# art
# rt o
# t of
#  of
# of a
# f ai
#  ai
# ai b
# i bu
#  but
# but
# ut o
# t on
#  onl
# only
# nly
# ly a
# y an
#  an
# an i
# n in
#  int
# inte
# ntel
# tell
# elli
# llig
# lige
# igen
# gent
# ent
# nt s
# t su
#  sub
# subs
# ubse
# bset
# set
# et o
# t of
#  of
# of m
# f ml
#  ml
# ml s
# l sh
#  sho
# shou
# houl
# ould
# uld
# ld b
# d be
#  be
# be c
# e co
#  con
# cons
# onsi
# nsid
# side
# ider
# dere
# ered
# red
# ed a
# d ai
#  ai.
# ai.m
# i.ma
# .mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g an
#  and
# and
# nd d
# d da
#  dat
# data
# ata
# ta m
# a mi
#  min
# mini
# inin
# ning
# ing
# ng o
# g of
#  oft
# ofte
# ften
# ten
# en e
# n em
#  emp
# empl
# mplo
# ploy
# loy
# oy t
# y th
#  the
# the
# he s
# e sa
#  sam
# same
# ame
# me m
# e me
#  met
# meth
# etho
# thod
# hods
# ods
# ds a
# s an
#  and
# and
# nd o
# d ov
#  ove
# over
# verl
# erla
# rlap
# lap
# ap s
# p si
#  sig
# sign
# igni
# gnif
# nifi
# ific
# fica
# ican
# cant
# antl
# ntly
# tly
# ly b
# y bu
#  but
# but
# ut w
# t wh
#  whi
# whil
# hile
# ile
# le m
# e ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng f
# g fo
#  foc
# focu
# ocus
# cuse
# uses
# ses
# es o
# s on
#  on
# on p
# n pr
#  pre
# pred
# redi
# edic
# dict
# icti
# ctio
# tion
# ion
# on b
# n ba
#  bas
# base
# ased
# sed
# ed o
# d on
#  on
# on k
# n kn
#  kno
# know
# nown
# own
# wn p
# n pr
#  pro
# prop
# rope
# oper
# pert
# erti
# rtie
# ties
# ies
# es l
# s le
#  lea
# lear
# earn
# arne
# rned
# ned
# ed f
# d fr
#  fro
# from
# rom
# om t
# m th
#  the
# the
# he t
# e tr
#  tra
# trai
# rain
# aini
# inin
# ning
# ing
# ng d
# g da
#  dat
# data
# ata
# ta d
# a da
#  dat
# data
# ata
# ta m
# a mi
#  min
# mini
# inin
# ning
# ing
# ng f
# g fo
#  foc
# focu
# ocus
# cuse
# uses
# ses
# es o
# s on
#  on
# on t
# n th
#  the
# the
# he d
# e di
#  dis
# disc
# isco
# scov
# cove
# over
# very
# ery
# ry o
# y of
#  of
# of p
# f pr
#  pre
# prev
# revi
# evio
# viou
# ious
# ousl
# usly
# sly
# ly u
# y un
#  unk
# unkn
# nkno
# know
# nown
# own
# wn p
# n pr
#  pro
# prop
# rope
# oper
# pert
# erti
# rtie
# ties
# ies
# es i
# s in
#  in
# in t
# n th
#  the
# the
# he d
# e da
#  dat
# data
# ata
# ta t
# a th
#  thi
# this
# his
# is i
# s is
#  is
# is t
# s th
#  the
# the
# he a
# e an
#  ana
# anal
# naly
# alys
# lysi
# ysis
# sis
# is s
# s st
#  ste
# step
# tep
# ep o
# p of
#  of
# of k
# f kn
#  kno
# know
# nowl
# owle
# wled
# ledg
# edge
# dge
# ge d
# e di
#  dis
# disc
# isco
# scov
# cove
# over
# very
# ery
# ry i
# y in
#  in
# in d
# n da
#  dat
# data
# atab
# taba
# abas
# base
# ases
# ses.
# es.
# s. d
# . da
#  dat
# data
# ata
# ta m
# a mi
#  min
# mini
# inin
# ning
# ing
# ng u
# g us
#  use
# uses
# ses
# es m
# s ma
#  man
# many
# any
# ny m
# y ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng m
# g me
#  met
# meth
# etho
# thod
# hods
# ods
# ds b
# s bu
#  but
# but
# ut w
# t wi
#  wit
# with
# ith
# th d
# h di
#  dif
# diff
# iffe
# ffer
# fere
# eren
# rent
# ent
# nt g
# t go
#  goa
# goal
# oals
# als
# ls o
# s on
#  on
# on t
# n th
#  the
# the
# he o
# e ot
#  oth
# othe
# ther
# her
# er h
# r ha
#  han
# hand
# and
# nd m
# d ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  als
# also
# lso
# so e
# o em
#  emp
# empl
# mplo
# ploy
# loys
# oys
# ys d
# s da
#  dat
# data
# ata
# ta m
# a mi
#  min
# mini
# inin
# ning
# ing
# ng m
# g me
#  met
# meth
# etho
# thod
# hods
# ods
# ds a
# s as
#  as
# as u
# s un
#  uns
# unsu
# nsup
# supe
# uper
# perv
# ervi
# rvis
# vise
# ised
# sed
# ed l
# d le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng o
# g or
#  or
# or a
# r as
#  as
# as a
# s a
#  a p
# a pr
#  pre
# prep
# repr
# epro
# proc
# roce
# oces
# cess
# essi
# ssin
# sing
# ing
# ng s
# g st
#  ste
# step
# tep
# ep t
# p to
#  to
# to i
# o im
#  imp
# impr
# mpro
# prov
# rove
# ove
# ve l
# e le
#  lea
# lear
# earn
# arne
# rner
# ner
# er a
# r ac
#  acc
# accu
# ccur
# cura
# urac
# racy
# acy.
# cy.
# y. m
# . mu
#  muc
# much
# uch
# ch o
# h of
#  of
# of t
# f th
#  the
# the
# he c
# e co
#  con
# conf
# onfu
# nfus
# fusi
# usio
# sion
# ion
# on b
# n be
#  bet
# betw
# etwe
# twee
# ween
# een
# en t
# n th
#  the
# thes
# hese
# ese
# se t
# e tw
#  two
# two
# wo r
# o re
#  res
# rese
# esea
# sear
# earc
# arch
# rch
# ch c
# h co
#  com
# comm
# ommu
# mmun
# muni
# unit
# niti
# itie
# ties
# ies
# es w
# s wh
#  whi
# whic
# hich
# ich
# ch d
# h do
#  do
# do o
# o of
#  oft
# ofte
# ften
# ten
# en h
# n ha
#  hav
# have
# ave
# ve s
# e se
#  sep
# sepa
# epar
# para
# arat
# rate
# ate
# te c
# e co
#  con
# conf
# onfe
# nfer
# fere
# eren
# renc
# ence
# nces
# ces
# es a
# s an
#  and
# and
# nd s
# d se
#  sep
# sepa
# epar
# para
# arat
# rate
# ate
# te j
# e jo
#  jou
# jour
# ourn
# urna
# rnal
# nals
# als
# ls e
# s ec
#  ecm
# ecml
# cml
# ml p
# l pk
#  pkd
# pkdd
# kdd
# dd b
# d be
#  bei
# bein
# eing
# ing
# ng a
# g a
#  a m
# a ma
#  maj
# majo
# ajor
# jor
# or e
# r ex
#  exc
# exce
# xcep
# cept
# epti
# ptio
# tion
# ion
# on c
# n co
#  com
# come
# omes
# mes
# es f
# s fr
#  fro
# from
# rom
# om t
# m th
#  the
# the
# he b
# e ba
#  bas
# basi
# asic
# sic
# ic a
# c as
#  ass
# assu
# ssum
# sump
# umpt
# mpti
# ptio
# tion
# ions
# ons
# ns t
# s th
#  the
# they
# hey
# ey w
# y wo
#  wor
# work
# ork
# rk w
# k wi
#  wit
# with
# ith
# th i
# h in
#  in
# in m
# n ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng p
# g pe
#  per
# perf
# erfo
# rfor
# form
# orma
# rman
# manc
# ance
# nce
# ce i
# e is
#  is
# is u
# s us
#  usu
# usua
# sual
# uall
# ally
# lly
# ly e
# y ev
#  eva
# eval
# valu
# alua
# luat
# uate
# ated
# ted
# ed w
# d wi
#  wit
# with
# ith
# th r
# h re
#  res
# resp
# espe
# spec
# pect
# ect
# ct t
# t to
#  to
# to t
# o th
#  the
# the
# he a
# e ab
#  abi
# abil
# bili
# ilit
# lity
# ity
# ty t
# y to
#  to
# to r
# o re
#  rep
# repr
# epro
# prod
# rodu
# oduc
# duce
# uce
# ce k
# e kn
#  kno
# know
# nown
# own
# wn k
# n kn
#  kno
# know
# nowl
# owle
# wled
# ledg
# edge
# dge
# ge w
# e wh
#  whi
# whil
# hile
# ile
# le i
# e in
#  in
# in k
# n kn
#  kno
# know
# nowl
# owle
# wled
# ledg
# edge
# dge
# ge d
# e di
#  dis
# disc
# isco
# scov
# cove
# over
# very
# ery
# ry a
# y an
#  and
# and
# nd d
# d da
#  dat
# data
# ata
# ta m
# a mi
#  min
# mini
# inin
# ning
# ing
# ng k
# g kd
#  kdd
# kdd
# dd t
# d th
#  the
# the
# he k
# e ke
#  key
# key
# ey t
# y ta
#  tas
# task
# ask
# sk i
# k is
#  is
# is t
# s th
#  the
# the
# he d
# e di
#  dis
# disc
# isco
# scov
# cove
# over
# very
# ery
# ry o
# y of
#  of
# of p
# f pr
#  pre
# prev
# revi
# evio
# viou
# ious
# ousl
# usly
# sly
# ly u
# y un
#  unk
# unkn
# nkno
# know
# nown
# own
# wn k
# n kn
#  kno
# know
# nowl
# owle
# wled
# ledg
# edge
# dge.
# ge.
# e. e
# . ev
#  eva
# eval
# valu
# alua
# luat
# uate
# ated
# ted
# ed w
# d wi
#  wit
# with
# ith
# th r
# h re
#  res
# resp
# espe
# spec
# pect
# ect
# ct t
# t to
#  to
# to k
# o kn
#  kno
# know
# nown
# own
# wn k
# n kn
#  kno
# know
# nowl
# owle
# wled
# ledg
# edge
# dge
# ge a
# e an
#  an
# an u
# n un
#  uni
# unin
# ninf
# info
# nfor
# form
# orme
# rmed
# med
# ed u
# d un
#  uns
# unsu
# nsup
# supe
# uper
# perv
# ervi
# rvis
# vise
# ised
# sed
# ed m
# d me
#  met
# meth
# etho
# thod
# hod
# od w
# d wi
#  wil
# will
# ill
# ll e
# l ea
#  eas
# easi
# asil
# sily
# ily
# ly b
# y be
#  be
# be o
# e ou
#  out
# outp
# utpe
# tper
# perf
# erfo
# rfor
# form
# orme
# rmed
# med
# ed b
# d by
#  by
# by o
# y ot
#  oth
# othe
# ther
# her
# er s
# r su
#  sup
# supe
# uper
# perv
# ervi
# rvis
# vise
# ised
# sed
# ed m
# d me
#  met
# meth
# etho
# thod
# hods
# ods
# ds w
# s wh
#  whi
# whil
# hile
# ile
# le i
# e in
#  in
# in a
# n a
#  a t
# a ty
#  typ
# typi
# ypic
# pica
# ical
# cal
# al k
# l kd
#  kdd
# kdd
# dd t
# d ta
#  tas
# task
# ask
# sk s
# k su
#  sup
# supe
# uper
# perv
# ervi
# rvis
# vise
# ised
# sed
# ed m
# d me
#  met
# meth
# etho
# thod
# hods
# ods
# ds c
# s ca
#  can
# cann
# anno
# nnot
# not
# ot b
# t be
#  be
# be u
# e us
#  use
# used
# sed
# ed d
# d du
#  due
# due
# ue t
# e to
#  to
# to t
# o th
#  the
# the
# he u
# e un
#  una
# unav
# nava
# avai
# vail
# aila
# ilab
# labi
# abil
# bili
# ilit
# lity
# ity
# ty o
# y of
#  of
# of t
# f tr
#  tra
# trai
# rain
# aini
# inin
# ning
# ing
# ng d
# g da
#  dat
# data
# ata.
# ta.m
# a.ma
# .mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  als
# also
# lso
# so h
# o ha
#  has
# has
# as i
# s in
#  int
# inti
# ntim
# tima
# imat
# mate
# ate
# te t
# e ti
#  tie
# ties
# ies
# es t
# s to
#  to
# to o
# o op
#  opt
# opti
# ptim
# timi
# imiz
# miza
# izat
# zati
# atio
# tion
# ion
# on m
# n ma
#  man
# many
# any
# ny l
# y le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng p
# g pr
#  pro
# prob
# robl
# oble
# blem
# lems
# ems
# ms a
# s ar
#  are
# are
# re f
# e fo
#  for
# form
# ormu
# rmul
# mula
# ulat
# late
# ated
# ted
# ed a
# d as
#  as
# as m
# s mi
#  min
# mini
# inim
# nimi
# imiz
# miza
# izat
# zati
# atio
# tion
# ion
# on o
# n of
#  of
# of s
# f so
#  som
# some
# ome
# me l
# e lo
#  los
# loss
# oss
# ss f
# s fu
#  fun
# func
# unct
# ncti
# ctio
# tion
# ion
# on o
# n on
#  on
# on a
# n a
#  a t
# a tr
#  tra
# trai
# rain
# aini
# inin
# ning
# ing
# ng s
# g se
#  set
# set
# et o
# t of
#  of
# of e
# f ex
#  exa
# exam
# xamp
# ampl
# mple
# ples
# les.
# es.
# s. l
# . lo
#  los
# loss
# oss
# ss f
# s fu
#  fun
# func
# unct
# ncti
# ctio
# tion
# ions
# ons
# ns e
# s ex
#  exp
# expr
# xpre
# pres
# ress
# ess
# ss t
# s th
#  the
# the
# he d
# e di
#  dis
# disc
# iscr
# scre
# crep
# repa
# epan
# panc
# ancy
# ncy
# cy b
# y be
#  bet
# betw
# etwe
# twee
# ween
# een
# en t
# n th
#  the
# the
# he p
# e pr
#  pre
# pred
# redi
# edic
# dict
# icti
# ctio
# tion
# ions
# ons
# ns o
# s of
#  of
# of t
# f th
#  the
# the
# he m
# e mo
#  mod
# mode
# odel
# del
# el b
# l be
#  bei
# bein
# eing
# ing
# ng t
# g tr
#  tra
# trai
# rain
# aine
# ined
# ned
# ed a
# d an
#  and
# and
# nd t
# d th
#  the
# the
# he a
# e ac
#  act
# actu
# ctua
# tual
# ual
# al p
# l pr
#  pro
# prob
# robl
# oble
# blem
# lem
# em i
# m in
#  ins
# inst
# nsta
# stan
# tanc
# ance
# nces
# ces
# es f
# s fo
#  for
# for
# or e
# r ex
#  exa
# exam
# xamp
# ampl
# mple
# ple
# le i
# e in
#  in
# in c
# n cl
#  cla
# clas
# lass
# assi
# ssif
# sifi
# ific
# fica
# icat
# cati
# atio
# tion
# ion
# on o
# n on
#  one
# one
# ne w
# e wa
#  wan
# want
# ants
# nts
# ts t
# s to
#  to
# to a
# o as
#  ass
# assi
# ssig
# sign
# ign
# gn a
# n a
#  a l
# a la
#  lab
# labe
# abel
# bel
# el t
# l to
#  to
# to i
# o in
#  ins
# inst
# nsta
# stan
# tanc
# ance
# nces
# ces
# es a
# s an
#  and
# and
# nd m
# d mo
#  mod
# mode
# odel
# dels
# els
# ls a
# s ar
#  are
# are
# re t
# e tr
#  tra
# trai
# rain
# aine
# ined
# ned
# ed t
# d to
#  to
# to c
# o co
#  cor
# corr
# orre
# rrec
# rect
# ectl
# ctly
# tly
# ly p
# y pr
#  pre
# pred
# redi
# edic
# dict
# ict
# ct t
# t th
#  the
# the
# he p
# e pr
#  pre
# prea
# reas
# eass
# assi
# ssig
# sign
# igne
# gned
# ned
# ed l
# d la
#  lab
# labe
# abel
# bels
# els
# ls o
# s of
#  of
# of a
# f a
#  a s
# a se
#  set
# set
# et o
# t of
#  of
# of e
# f ex
#  exa
# exam
# xamp
# ampl
# mple
# ples
# les.
# es.t
# s.th
# .the
# the
# he d
# e di
#  dif
# diff
# iffe
# ffer
# fere
# eren
# renc
# ence
# nce
# ce b
# e be
#  bet
# betw
# etwe
# twee
# ween
# een
# en o
# n op
#  opt
# opti
# ptim
# timi
# imiz
# miza
# izat
# zati
# atio
# tion
# ion
# on a
# n an
#  and
# and
# nd m
# d ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g ar
#  ari
# aris
# rise
# ises
# ses
# es f
# s fr
#  fro
# from
# rom
# om t
# m th
#  the
# the
# he g
# e go
#  goa
# goal
# oal
# al o
# l of
#  of
# of g
# f ge
#  gen
# gene
# ener
# nera
# eral
# rali
# aliz
# liza
# izat
# zati
# atio
# tion
# ion
# on w
# n wh
#  whi
# whil
# hile
# ile
# le o
# e op
#  opt
# opti
# ptim
# timi
# imiz
# miza
# izat
# zati
# atio
# tion
# ion
# on a
# n al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms c
# s ca
#  can
# can
# an m
# n mi
#  min
# mini
# inim
# nimi
# imiz
# mize
# ize
# ze t
# e th
#  the
# the
# he l
# e lo
#  los
# loss
# oss
# ss o
# s on
#  on
# on a
# n a
#  a t
# a tr
#  tra
# trai
# rain
# aini
# inin
# ning
# ing
# ng s
# g se
#  set
# set
# et m
# t ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng i
# g is
#  is
# is c
# s co
#  con
# conc
# once
# ncer
# cern
# erne
# rned
# ned
# ed w
# d wi
#  wit
# with
# ith
# th m
# h mi
#  min
# mini
# inim
# nimi
# imiz
# mizi
# izin
# zing
# ing
# ng t
# g th
#  the
# the
# he l
# e lo
#  los
# loss
# oss
# ss o
# s on
#  on
# on u
# n un
#  uns
# unse
# nsee
# seen
# een
# en s
# n sa
#  sam
# samp
# ampl
# mple
# ples
# les.
# es.
# s. c
# . ch
#  cha
# char
# hara
# arac
# ract
# acte
# cter
# teri
# eriz
# rizi
# izin
# zing
# ing
# ng t
# g th
#  the
# the
# he g
# e ge
#  gen
# gene
# ener
# nera
# eral
# rali
# aliz
# liza
# izat
# zati
# atio
# tion
# ion
# on o
# n of
#  of
# of v
# f va
#  var
# vari
# ario
# riou
# ious
# ous
# us l
# s le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms i
# s is
#  is
# is a
# s an
#  an
# an a
# n ac
#  act
# acti
# ctiv
# tive
# ive
# ve t
# e to
#  top
# topi
# opic
# pic
# ic o
# c of
#  of
# of c
# f cu
#  cur
# curr
# urre
# rren
# rent
# ent
# nt r
# t re
#  res
# rese
# esea
# sear
# earc
# arch
# rch
# ch e
# h es
#  esp
# espe
# spec
# peci
# ecia
# cial
# iall
# ally
# lly
# ly f
# y fo
#  for
# for
# or d
# r de
#  dee
# deep
# eep
# ep l
# p le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms.
# ms.m
# s.ma
# .mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g an
#  and
# and
# nd s
# d st
#  sta
# stat
# tati
# atis
# tist
# isti
# stic
# tics
# ics
# cs a
# s ar
#  are
# are
# re c
# e cl
#  clo
# clos
# lose
# osel
# sely
# ely
# ly r
# y re
#  rel
# rela
# elat
# late
# ated
# ted
# ed f
# d fi
#  fie
# fiel
# ield
# elds
# lds
# ds i
# s in
#  in
# in t
# n te
#  ter
# term
# erms
# rms
# ms o
# s of
#  of
# of m
# f me
#  met
# meth
# etho
# thod
# hods
# ods
# ds b
# s bu
#  but
# but
# ut d
# t di
#  dis
# dist
# isti
# stin
# tinc
# inct
# nct
# ct i
# t in
#  in
# in t
# n th
#  the
# thei
# heir
# eir
# ir p
# r pr
#  pri
# prin
# rinc
# inci
# ncip
# cipa
# ipal
# pal
# al g
# l go
#  goa
# goal
# oal
# al s
# l st
#  sta
# stat
# tati
# atis
# tist
# isti
# stic
# tics
# ics
# cs d
# s dr
#  dra
# draw
# raws
# aws
# ws p
# s po
#  pop
# popu
# opul
# pula
# ulat
# lati
# atio
# tion
# ion
# on i
# n in
#  inf
# infe
# nfer
# fere
# eren
# renc
# ence
# nces
# ces
# es f
# s fr
#  fro
# from
# rom
# om a
# m a
#  a s
# a sa
#  sam
# samp
# ampl
# mple
# ple
# le w
# e wh
#  whi
# whil
# hile
# ile
# le m
# e ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng f
# g fi
#  fin
# find
# inds
# nds
# ds g
# s ge
#  gen
# gene
# ...
# ing
# ng t
# g th
#  the
# the
# he b
# e bi
#  bia
# bias
# ias
# as b
# s by
#  by
# by s
# y sc
#  sco
# scor
# cori
# orin
# ring
# ing
# ng j
# g jo
#  job
# job
# ob a
# b ap
#  app
# appl
# ppli
# plic
# lica
# ican
# cant
# ants
# nts
# ts b
# s by
#  by
# by s
# y si
#  sim
# simi
# imil
# mila
# ilar
# lari
# arit
# rity
# ity
# ty t
# y to
#  to
# to p
# o pr
#  pre
# prev
# revi
# evio
# viou
# ious
# ous
# us s
# s su
#  suc
# succ
# ucce
# cces
# cess
# essf
# ssfu
# sful
# ful
# ul a
# l ap
#  app
# appl
# ppli
# plic
# lica
# ican
# cant
# ants
# nts.
# ts.
# s. r
# . re
#  res
# resp
# espo
# spon
# pons
# onsi
# nsib
# sibl
# ible
# ble
# le c
# e co
#  col
# coll
# olle
# llec
# lect
# ecti
# ctio
# tion
# ion
# on o
# n of
#  of
# of d
# f da
#  dat
# data
# ata
# ta a
# a an
#  and
# and
# nd d
# d do
#  doc
# docu
# ocum
# cume
# umen
# ment
# enta
# ntat
# tati
# atio
# tion
# ion
# on o
# n of
#  of
# of a
# f al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thmi
# hmic
# mic
# ic r
# c ru
#  rul
# rule
# ules
# les
# es u
# s us
#  use
# used
# sed
# ed b
# d by
#  by
# by a
# y a
#  a s
# a sy
#  sys
# syst
# yste
# stem
# tem
# em t
# m th
#  thu
# thus
# hus
# us i
# s is
#  is
# is a
# s a
#  a c
# a cr
#  cri
# crit
# riti
# itic
# tica
# ical
# cal
# al p
# l pa
#  par
# part
# art
# rt o
# t of
#  of
# of m
# f ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing.
# ng.a
# g.ai
# .ai
# ai c
# i ca
#  can
# can
# an b
# n be
#  be
# be w
# e we
#  wel
# well
# elle
# lleq
# lequ
# equi
# quip
# uipp
# ippe
# pped
# ped
# ed t
# d to
#  to
# to m
# o ma
#  mak
# make
# ake
# ke d
# e de
#  dec
# deci
# ecis
# cisi
# isio
# sion
# ions
# ons
# ns i
# s in
#  in
# in t
# n te
#  tec
# tech
# echn
# chni
# hnic
# nica
# ical
# cal
# al f
# l fi
#  fie
# fiel
# ield
# elds
# lds
# ds w
# s wh
#  whi
# whic
# hich
# ich
# ch r
# h re
#  rel
# rely
# ely
# ly h
# y he
#  hea
# heav
# eavi
# avil
# vily
# ily
# ly o
# y on
#  on
# on d
# n da
#  dat
# data
# ata
# ta a
# a an
#  and
# and
# nd h
# d hi
#  his
# hist
# isto
# stor
# tori
# oric
# rica
# ical
# cal
# al i
# l in
#  inf
# info
# nfor
# form
# orma
# rmat
# mati
# atio
# tion
# ion.
# on.
# n. t
# . th
#  the
# thes
# hese
# ese
# se d
# e de
#  dec
# deci
# ecis
# cisi
# isio
# sion
# ions
# ons
# ns r
# s re
#  rel
# rely
# ely
# ly o
# y on
#  on
# on t
# n th
#  the
# the
# he o
# e ob
#  obj
# obje
# bjec
# ject
# ecti
# ctiv
# tivi
# ivit
# vity
# ity
# ty a
# y an
#  and
# and
# nd l
# d lo
#  log
# logi
# ogic
# gica
# ical
# cal
# al r
# l re
#  rea
# reas
# easo
# ason
# soni
# onin
# ning
# ing.
# ng.
# g. b
# . be
#  bec
# beca
# ecau
# caus
# ause
# use
# se h
# e hu
#  hum
# huma
# uman
# man
# an l
# n la
#  lan
# lang
# angu
# ngua
# guag
# uage
# ages
# ges
# es c
# s co
#  con
# cont
# onta
# ntai
# tain
# ain
# in b
# n bi
#  bia
# bias
# iase
# ases
# ses
# es m
# s ma
#  mac
# mach
# achi
# chin
# hine
# ines
# nes
# es t
# s tr
#  tra
# trai
# rain
# aine
# ined
# ned
# ed o
# d on
#  on
# on l
# n la
#  lan
# lang
# angu
# ngua
# guag
# uage
# age
# ge c
# e co
#  cor
# corp
# orpo
# rpor
# pora
# ora
# ra w
# a wi
#  wil
# will
# ill
# ll n
# l ne
#  nec
# nece
# eces
# cess
# essa
# ssar
# sari
# aril
# rily
# ily
# ly a
# y al
#  als
# also
# lso
# so l
# o le
#  lea
# lear
# earn
# arn
# rn t
# n th
#  the
# thes
# hese
# ese
# se b
# e bi
#  bia
# bias
# iase
# ases
# ses.
# es.o
# s.ot
# .oth
# othe
# ther
# her
# er f
# r fo
#  for
# form
# orms
# rms
# ms o
# s of
#  of
# of e
# f et
#  eth
# ethi
# thic
# hica
# ical
# cal
# al c
# l ch
#  cha
# chal
# hall
# alle
# llen
# leng
# enge
# nges
# ges
# es n
# s no
#  not
# not
# ot r
# t re
#  rel
# rela
# elat
# late
# ated
# ted
# ed t
# d to
#  to
# to p
# o pe
#  per
# pers
# erso
# rson
# sona
# onal
# nal
# al b
# l bi
#  bia
# bias
# iase
# ases
# ses
# es a
# s ar
#  are
# are
# re s
# e se
#  see
# seen
# een
# en i
# n in
#  in
# in h
# n he
#  hea
# heal
# ealt
# alth
# lth
# th c
# h ca
#  car
# care
# are.
# re.
# e. t
# . th
#  the
# ther
# here
# ere
# re a
# e ar
#  are
# are
# re c
# e co
#  con
# conc
# once
# ncer
# cern
# erns
# rns
# ns a
# s am
#  amo
# amon
# mong
# ong
# ng h
# g he
#  hea
# heal
# ealt
# alth
# lth
# th c
# h ca
#  car
# care
# are
# re p
# e pr
#  pro
# prof
# rofe
# ofes
# fess
# essi
# ssio
# sion
# iona
# onal
# nals
# als
# ls t
# s th
#  tha
# that
# hat
# at t
# t th
#  the
# thes
# hese
# ese
# se s
# e sy
#  sys
# syst
# yste
# stem
# tems
# ems
# ms m
# s mi
#  mig
# migh
# ight
# ght
# ht n
# t no
#  not
# not
# ot b
# t be
#  be
# be d
# e de
#  des
# desi
# esig
# sign
# igne
# gned
# ned
# ed i
# d in
#  in
# in t
# n th
#  the
# the
# he p
# e pu
#  pub
# publ
# ubli
# blic
# lics
# ics
# cs i
# s in
#  int
# inte
# nter
# tere
# eres
# rest
# est
# st b
# t bu
#  but
# but
# ut a
# t as
#  as
# as i
# s in
#  inc
# inco
# ncom
# come
# omeg
# mege
# egen
# gene
# ener
# nera
# erat
# rati
# atin
# ting
# ing
# ng m
# g ma
#  mac
# mach
# achi
# chin
# hine
# ines
# nes.
# es.
# s. t
# . th
#  thi
# this
# his
# is i
# s is
#  is
# is e
# s es
#  esp
# espe
# spec
# peci
# ecia
# cial
# iall
# ally
# lly
# ly t
# y tr
#  tru
# true
# rue
# ue i
# e in
#  in
# in t
# n th
#  the
# the
# he u
# e un
#  uni
# unit
# nite
# ited
# ted
# ed s
# d st
#  sta
# stat
# tate
# ates
# tes
# es w
# s wh
#  whe
# wher
# here
# ere
# re t
# e th
#  the
# ther
# here
# ere
# re i
# e is
#  is
# is a
# s a
#  a l
# a lo
#  lon
# long
# ongs
# ngst
# gsta
# stan
# tand
# andi
# ndin
# ding
# ing
# ng e
# g et
#  eth
# ethi
# thic
# hica
# ical
# cal
# al d
# l di
#  dil
# dile
# ilem
# lemm
# emma
# mma
# ma o
# a of
#  of
# of i
# f im
#  imp
# impr
# mpro
# prov
# rovi
# ovin
# ving
# ing
# ng h
# g he
#  hea
# heal
# ealt
# alth
# lth
# th c
# h ca
#  car
# care
# are
# re b
# e bu
#  but
# but
# ut a
# t al
#  als
# also
# lso
# so i
# o in
#  inc
# incr
# ncre
# crea
# reas
# ease
# ase
# se p
# e pr
#  pro
# prof
# rofi
# ofit
# fits
# its.
# ts.
# s. f
# . fo
#  for
# for
# or e
# r ex
#  exa
# exam
# xamp
# ampl
# mple
# ple
# le t
# e th
#  the
# the
# he a
# e al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms c
# s co
#  cou
# coul
# ould
# uld
# ld b
# d be
#  be
# be d
# e de
#  des
# desi
# esig
# sign
# igne
# gned
# ned
# ed t
# d to
#  to
# to p
# o pr
#  pro
# prov
# rovi
# ovid
# vide
# ide
# de p
# e pa
#  pat
# pati
# atie
# tien
# ient
# ents
# nts
# ts w
# s wi
#  wit
# with
# ith
# th u
# h un
#  unn
# unne
# nnec
# nece
# eces
# cess
# essa
# ssar
# sary
# ary
# ry t
# y te
#  tes
# test
# ests
# sts
# ts o
# s or
#  or
# or m
# r me
#  med
# medi
# edic
# dica
# icat
# cati
# atio
# tion
# ion
# on i
# n in
#  in
# in w
# n wh
#  whi
# whic
# hich
# ich
# ch t
# h th
#  the
# the
# he a
# e al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms p
# s pr
#  pro
# prop
# ropr
# opri
# prie
# riet
# ieta
# etar
# tary
# ary
# ry o
# y ow
#  own
# owne
# wner
# ners
# ers
# rs h
# s ho
#  hol
# hold
# old
# ld s
# d st
#  sta
# stak
# take
# akes
# kes.
# es.
# s. t
# . th
#  the
# ther
# here
# ere
# re i
# e is
#  is
# is
# s  p
#   po
#  pot
# pote
# oten
# tent
# enti
# ntia
# tial
# ial
# al f
# l fo
#  for
# for
# or m
# r ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng i
# g in
#  in
# in h
# n he
#  hea
# heal
# ealt
# alth
# lth
# th c
# h ca
#  car
# care
# are
# re t
# e to
#  to
# to p
# o pr
#  pro
# prov
# rovi
# ovid
# vide
# ide
# de p
# e pr
#  pro
# prof
# rofe
# ofes
# fess
# essi
# ssio
# sion
# iona
# onal
# nals
# als
# ls a
# s an
#  an
# an a
# n ad
#  add
# addi
# ddit
# diti
# itio
# tion
# iona
# onal
# nal
# al t
# l to
#  too
# tool
# ool
# ol t
# l to
#  to
# to d
# o di
#  dia
# diag
# iagn
# agno
# gnos
# nose
# ose
# se m
# e me
#  med
# medi
# edic
# dica
# icat
# cate
# ate
# te a
# e an
#  and
# and
# nd p
# d pl
#  pla
# plan
# lan
# an r
# n re
#  rec
# reco
# ecov
# cove
# over
# very
# ery
# ry p
# y pa
#  pat
# path
# aths
# ths
# hs f
# s fo
#  for
# for
# or p
# r pa
#  pat
# pati
# atie
# tien
# ient
# ents
# nts
# ts b
# s bu
#  but
# but
# ut t
# t th
#  thi
# this
# his
# is r
# s re
#  req
# requ
# equi
# quir
# uire
# ires
# res
# es t
# s th
#  the
# thes
# hese
# ese
# se b
# e bi
#  bia
# bias
# iase
# ases
# ses
# es t
# s to
#  to
# to b
# o be
#  be
# be m
# e mi
#  mit
# miti
# itig
# tiga
# igat
# gate
# ated
# ted.
# ed.s
# d.si
# .sin
# sinc
# ince
# nce
# ce t
# e th
#  the
# the
# he s
# e s
#  s a
# s ad
#  adv
# adva
# dvan
# vanc
# ance
# nces
# ces
# es i
# s in
#  in
# in b
# n bo
#  bot
# both
# oth
# th m
# h ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms a
# s an
#  and
# and
# nd c
# d co
#  com
# comp
# ompu
# mput
# pute
# uter
# ter
# er h
# r ha
#  har
# hard
# ardw
# rdwa
# dwar
# ware
# are
# re h
# e ha
#  hav
# have
# ave
# ve l
# e le
#  led
# led
# ed t
# d to
#  to
# to m
# o mo
#  mor
# more
# ore
# re e
# e ef
#  eff
# effi
# ffic
# fici
# icie
# cien
# ient
# ent
# nt m
# t me
#  met
# meth
# etho
# thod
# hods
# ods
# ds f
# s fo
#  for
# for
# or t
# r tr
#  tra
# trai
# rain
# aini
# inin
# ning
# ing
# ng d
# g de
#  dee
# deep
# eep
# ep n
# p ne
#  neu
# neur
# eura
# ural
# ral
# al n
# l ne
#  net
# netw
# etwo
# twor
# work
# orks
# rks
# ks a
# s a
#  a p
# a pa
#  par
# part
# arti
# rtic
# ticu
# icul
# cula
# ular
# lar
# ar n
# r na
#  nar
# narr
# arro
# rrow
# row
# ow s
# w su
#  sub
# subd
# ubdo
# bdom
# doma
# omai
# main
# ain
# in o
# n of
#  of
# of m
# f ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng t
# g th
#  tha
# that
# hat
# at c
# t co
#  con
# cont
# onta
# ntai
# tain
# ain
# in m
# n ma
#  man
# many
# any
# ny l
# y la
#  lay
# laye
# ayer
# yers
# ers
# rs o
# s of
#  of
# of n
# f no
#  non
# nonl
# onli
# nlin
# line
# inea
# near
# ear
# ar h
# r hi
#  hid
# hidd
# idde
# dden
# den
# en u
# n un
#  uni
# unit
# nits
# its.
# ts.
# s. b
# . by
#  by
# by
# y  g
#   gr
#  gra
# grap
# raph
# aphi
# phic
# hic
# ic p
# c pr
#  pro
# proc
# roce
# oces
# cess
# essi
# ssin
# sing
# ing
# ng u
# g un
#  uni
# unit
# nits
# its
# ts g
# s gp
#  gpu
# gpus
# pus
# us o
# s of
#  oft
# ofte
# ften
# ten
# en w
# n wi
#  wit
# with
# ith
# th a
# h ai
#  ais
# aisp
# ispe
# spec
# peci
# ecif
# cifi
# ific
# fic
# ic e
# c en
#  enh
# enha
# nhan
# hanc
# ance
# ncem
# ceme
# emen
# ment
# ents
# nts
# ts h
# s ha
#  had
# had
# ad d
# d di
#  dis
# disp
# ispl
# spla
# plac
# lace
# aced
# ced
# ed c
# d cp
#  cpu
# cpus
# pus
# us a
# s as
#  as
# as t
# s th
#  the
# the
# he d
# e do
#  dom
# domi
# omin
# mina
# inan
# nant
# ant
# nt m
# t me
#  met
# meth
# etho
# thod
# hod
# od o
# d of
#  of
# of t
# f tr
#  tra
# trai
# rain
# aini
# inin
# ning
# ing
# ng l
# g la
#  lar
# larg
# arge
# rges
# gesc
# esca
# scal
# cale
# ale
# le c
# e co
#  com
# comm
# omme
# mmer
# merc
# erci
# rcia
# cial
# ial
# al c
# l cl
#  clo
# clou
# loud
# oud
# ud a
# d ai
#  ai.
# ai.
# i. o
# . op
#  ope
# open
# pena
# enai
# nai
# ai e
# i es
#  est
# esti
# stim
# tima
# imat
# mate
# ated
# ted
# ed t
# d th
#  the
# the
# he h
# e ha
#  har
# hard
# ardw
# rdwa
# dwar
# ware
# are
# re c
# e co
#  com
# comp
# ompu
# mput
# puti
# utin
# ting
# ing
# ng u
# g us
#  use
# used
# sed
# ed i
# d in
#  in
# in t
# n th
#  the
# the
# he l
# e la
#  lar
# larg
# arge
# rges
# gest
# est
# st d
# t de
#  dee
# deep
# eep
# ep l
# p le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng p
# g pr
#  pro
# proj
# roje
# ojec
# ject
# ects
# cts
# ts f
# s fr
#  fro
# from
# rom
# om a
# m al
#  ale
# alex
# lexn
# exne
# xnet
# net
# et
# t  t
#   to
#  to
# to a
# o al
#  alp
# alph
# lpha
# phaz
# haze
# azer
# zero
# ero
# ro
# o  a
#   an
#  and
# and
# nd f
# d fo
#  fou
# foun
# ound
# und
# nd a
# d a
#  a f
# a fo
#  fol
# fold
# old
# ld i
# d in
#  inc
# incr
# ncre
# crea
# reas
# ease
# ase
# se i
# e in
#  in
# in t
# n th
#  the
# the
# he a
# e am
#  amo
# amou
# moun
# ount
# unt
# nt o
# t of
#  of
# of c
# f co
#  com
# comp
# ompu
# mput
# pute
# ute
# te r
# e re
#  req
# requ
# equi
# quir
# uire
# ired
# red
# ed w
# d wi
#  wit
# with
# ith
# th a
# h a
#  a d
# a do
#  dou
# doub
# oubl
# ubli
# blin
# ling
# ingt
# ngti
# gtim
# time
# ime
# me t
# e tr
#  tre
# tren
# rend
# endl
# ndli
# dlin
# line
# ine
# ne o
# e of
#  of
# of .
# f .
#  . m
# . mo
#  mon
# mont
# onth
# nths
# ths.
# hs.a
# s.a
# .a p
# a ph
#  phy
# phys
# hysi
# ysic
# sica
# ical
# cal
# al n
# l ne
#  neu
# neur
# eura
# ural
# ral
# al n
# l ne
#  net
# netw
# etwo
# twor
# work
# ork
# rk o
# k or
#  or
# or n
# r ne
#  neu
# neur
# euro
# urom
# romo
# omor
# morp
# orph
# rphi
# phic
# hic
# ic c
# c co
#  com
# comp
# ompu
# mput
# pute
# uter
# ter
# er
# r  i
#   is
#  is
# is a
# s a
#  a t
# a ty
#  typ
# type
# ype
# pe o
# e of
#  of
# of a
# f ar
#  art
# arti
# rtif
# tifi
# ific
# fici
# icia
# cial
# ial
# al n
# l ne
#  neu
# neur
# eura
# ural
# ral
# al n
# l ne
#  net
# netw
# etwo
# twor
# work
# ork
# rk i
# k in
#  in
# in w
# n wh
#  whi
# whic
# hich
# ich
# ch a
# h an
#  an
# an e
# n el
#  ele
# elec
# lect
# ectr
# ctri
# tric
# rica
# ical
# call
# ally
# lly
# ly a
# y ad
#  adj
# adju
# djus
# just
# usta
# stab
# tabl
# able
# ble
# le m
# e ma
#  mat
# mate
# ater
# teri
# eria
# rial
# ial
# al i
# l is
#  is
# is u
# s us
#  use
# used
# sed
# ed t
# d to
#  to
# to e
# o em
#  emu
# emul
# mula
# ulat
# late
# ate
# te t
# e th
#  the
# the
# he f
# e fu
#  fun
# func
# unct
# ncti
# ctio
# tion
# ion
# on o
# n of
#  of
# of a
# f a
#  a n
# a ne
#  neu
# neur
# eura
# ural
# ral
# al s
# l sy
#  syn
# syna
# ynap
# naps
# apse
# pse.
# se.
# e. p
# . ph
#  phy
# phys
# hysi
# ysic
# sica
# ical
# cal
# al n
# l ne
#  neu
# neur
# eura
# ural
# ral
# al n
# l ne
#  net
# netw
# etwo
# twor
# work
# ork
# rk i
# k is
#  is
# is u
# s us
#  use
# used
# sed
# ed t
# d to
#  to
# to e
# o em
#  emp
# emph
# mpha
# phas
# hasi
# asiz
# size
# ize
# ze t
# e th
#  the
# the
# he r
# e re
#  rel
# reli
# elia
# lian
# ianc
# ance
# nce
# ce o
# e on
#  on
# on p
# n ph
#  phy
# phys
# hysi
# ysic
# sica
# ical
# cal
# al h
# l ha
#  har
# hard
# ardw
# rdwa
# dwar
# ware
# are
# re u
# e us
#  use
# used
# sed
# ed t
# d to
#  to
# to e
# o em
#  emu
# emul
# mula
# ulat
# late
# ate
# te n
# e ne
#  neu
# neur
# euro
# uron
# rons
# ons
# ns a
# s as
#  as
# as o
# s op
#  opp
# oppo
# ppos
# pose
# osed
# sed
# ed t
# d to
#  to
# to s
# o so
#  sof
# soft
# oftw
# ftwa
# twar
# ware
# areb
# reba
# ebas
# base
# ased
# sed
# ed a
# d ap
#  app
# appr
# ppro
# proa
# roac
# oach
# ache
# ches
# hes.
# es.
# s. m
# . mo
#  mor
# more
# ore
# re g
# e ge
#  gen
# gene
# ener
# nera
# eral
# rall
# ally
# lly
# ly t
# y th
#  the
# the
# he t
# e te
#  ter
# term
# erm
# rm i
# m is
#  is
# is a
# s ap
#  app
# appl
# ppli
# plic
# lica
# icab
# cabl
# able
# ble
# le t
# e to
#  to
# to o
# o ot
#  oth
# othe
# ther
# her
# er a
# r ar
#  art
# arti
# rtif
# tifi
# ific
# fici
# icia
# cial
# ial
# al n
# l ne
#  neu
# neur
# eura
# ural
# ral
# al n
# l ne
#  net
# netw
# etwo
# twor
# work
# orks
# rks
# ks i
# s in
#  in
# in w
# n wh
#  whi
# whic
# hich
# ich
# ch a
# h a
#  a m
# a me
#  mem
# memr
# emri
# mris
# rist
# isto
# stor
# tor
# or o
# r or
#  or
# or o
# r ot
#  oth
# othe
# ther
# her
# er e
# r el
#  ele
# elec
# lect
# ectr
# ctri
# tric
# rica
# ical
# call
# ally
# lly
# ly a
# y ad
#  adj
# adju
# djus
# just
# usta
# stab
# tabl
# able
# ble
# le r
# e re
#  res
# resi
# esis
# sist
# ista
# stan
# tanc
# ance
# nce
# ce m
# e ma
#  mat
# mate
# ater
# teri
# eria
# rial
# ial
# al i
# l is
#  is
# is u
# s us
#  use
# used
# sed
# ed t
# d to
#  to
# to e
# o em
#  emu
# emul
# mula
# ulat
# late
# ate
# te a
# e a
#  a n
# a ne
#  neu
# neur
# eura
# ural
# ral
# al s
# l sy
#  syn
# syna
# ynap
# naps
# apse
# pse.
# se.e
# e.em
# .emb
# embe
# mbed
# bedd
# edde
# dded
# ded
# ed m
# d ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng i
# g is
#  is
# is a
# s a
#  a s
# a su
#  sub
# subf
# ubfi
# bfie
# fiel
# ield
# eld
# ld o
# d of
#  of
# of m
# f ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng w
# g wh
#  whe
# wher
# here
# ere
# re t
# e th
#  the
# the
# he m
# e ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng m
# g mo
#  mod
# mode
# odel
# del
# el i
# l is
#  is
# is r
# s ru
#  run
# run
# un o
# n on
#  on
# on e
# n em
#  emb
# embe
# mbed
# bedd
# edde
# dded
# ded
# ed s
# d sy
#  sys
# syst
# yste
# stem
# tems
# ems
# ms w
# s wi
#  wit
# with
# ith
# th l
# h li
#  lim
# limi
# imit
# mite
# ited
# ted
# ed c
# d co
#  com
# comp
# ompu
# mput
# puti
# utin
# ting
# ing
# ng r
# g re
#  res
# reso
# esou
# sour
# ourc
# urce
# rces
# ces
# es s
# s su
#  suc
# such
# uch
# ch a
# h as
#  as
# as w
# s we
#  wea
# wear
# eara
# arab
# rabl
# able
# ble
# le c
# e co
#  com
# comp
# ompu
# mput
# pute
# uter
# ters
# ers
# rs e
# s ed
#  edg
# edge
# dge
# ge d
# e de
#  dev
# devi
# evic
# vice
# ices
# ces
# es a
# s an
#  and
# and
# nd m
# d mi
#  mic
# micr
# icro
# croc
# roco
# ocon
# cont
# ontr
# ntro
# trol
# roll
# olle
# ller
# lers
# ers.
# rs.
# s. r
# . ru
#  run
# runn
# unni
# nnin
# ning
# ing
# ng m
# g ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng m
# g mo
#  mod
# mode
# odel
# del
# el i
# l in
#  in
# in e
# n em
#  emb
# embe
# mbed
# bedd
# edde
# dded
# ded
# ed d
# d de
#  dev
# devi
# evic
# vice
# ices
# ces
# es r
# s re
#  rem
# remo
# emov
# move
# oves
# ves
# es t
# s th
#  the
# the
# he n
# e ne
#  nee
# need
# eed
# ed f
# d fo
#  for
# for
# or t
# r tr
#  tra
# tran
# rans
# ansf
# nsfe
# sfer
# ferr
# erri
# rrin
# ring
# ing
# ng a
# g an
#  and
# and
# nd s
# d st
#  sto
# stor
# tori
# orin
# ring
# ing
# ng d
# g da
#  dat
# data
# ata
# ta o
# a on
#  on
# on c
# n cl
#  clo
# clou
# loud
# oud
# ud s
# d se
#  ser
# serv
# erve
# rver
# vers
# ers
# rs f
# s fo
#  for
# for
# or f
# r fu
#  fur
# furt
# urth
# rthe
# ther
# her
# er p
# r pr
#  pro
# proc
# roce
# oces
# cess
# essi
# ssin
# sing
# ing
# ng h
# g he
#  hen
# henc
# ence
# ncef
# cefo
# efor
# fort
# orth
# rth
# th r
# h re
#  red
# redu
# educ
# duci
# ucin
# cing
# ing
# ng d
# g da
#  dat
# data
# ata
# ta b
# a br
#  bre
# brea
# reac
# each
# ache
# ches
# hes
# es a
# s an
#  and
# and
# nd p
# d pr
#  pri
# priv
# riva
# ivac
# vacy
# acy
# cy l
# y le
#  lea
# leak
# eaks
# aks
# ks h
# s ha
#  hap
# happ
# appe
# ppen
# peni
# enin
# ning
# ing
# ng b
# g be
#  bec
# beca
# ecau
# caus
# ause
# use
# se o
# e of
#  of
# of t
# f tr
#  tra
# tran
# rans
# ansf
# nsfe
# sfer
# ferr
# erri
# rrin
# ring
# ing
# ng d
# g da
#  dat
# data
# ata
# ta a
# a an
#  and
# and
# nd a
# d al
#  als
# also
# lso
# so m
# o mi
#  min
# mini
# inim
# nimi
# imiz
# mize
# izes
# zes
# es t
# s th
#  the
# thef
# heft
# eft
# ft o
# t of
#  of
# of i
# f in
#  int
# inte
# ntel
# tell
# elle
# llec
# lect
# ectu
# ctua
# tual
# ual
# al p
# l pr
#  pro
# prop
# rope
# oper
# pert
# erti
# rtie
# ties
# ies
# es p
# s pe
#  per
# pers
# erso
# rson
# sona
# onal
# nal
# al d
# l da
#  dat
# data
# ata
# ta a
# a an
#  and
# and
# nd b
# d bu
#  bus
# busi
# usin
# sine
# ines
# ness
# ess
# ss s
# s se
#  sec
# secr
# ecre
# cret
# rets
# ets.
# ts.
# s. e
# . em
#  emb
# embe
# mbed
# bedd
# edde
# dded
# ded
# ed m
# d ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng c
# g co
#  cou
# coul
# ould
# uld
# ld b
# d be
#  be
# be a
# e ap
#  app
# appl
# ppli
# plie
# lied
# ied
# ed t
# d th
#  thr
# thro
# hrou
# roug
# ough
# ugh
# gh s
# h se
#  sev
# seve
# ever
# vera
# eral
# ral
# al t
# l te
#  tec
# tech
# echn
# chni
# hniq
# niqu
# ique
# ques
# ues
# es i
# s in
#  inc
# incl
# nclu
# clud
# ludi
# udin
# ding
# ing
# ng h
# g ha
#  har
# hard
# ardw
# rdwa
# dwar
# ware
# are
# re a
# e ac
#  acc
# acce
# ccel
# cele
# eler
# lera
# erat
# rati
# atio
# tion
# ion
# on u
# n us
#  usi
# usin
# sing
# ing
# ng a
# g ap
#  app
# appr
# ppro
# prox
# roxi
# oxim
# xima
# imat
# mate
# ate
# te c
# e co
#  com
# comp
# ompu
# mput
# puti
# utin
# ting
# ing
# ng o
# g op
#  opt
# opti
# ptim
# timi
# imiz
# miza
# izat
# zati
# atio
# tion
# ion
# on o
# n of
#  of
# of m
# f ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng m
# g mo
#  mod
# mode
# odel
# dels
# els
# ls a
# s an
#  and
# and
# nd m
# d ma
#  man
# many
# any
# ny m
# y mo
#  mor
# more
# ore.
# re.s
# e.so
# .sof
# soft
# oftw
# ftwa
# twar
# ware
# are
# re s
# e su
#  sui
# suit
# uite
# ites
# tes
# es c
# s co
#  con
# cont
# onta
# ntai
# tain
# aini
# inin
# ning
# ing
# ng a
# g a
#  a v
# a va
#  var
# vari
# arie
# riet
# iety
# ety
# ty o
# y of
#  of
# of m
# f ma
#  mac
# mach
# achi
# chin
# hine
# ine
# ne l
# e le
#  lea
# lear
# earn
# arni
# rnin
# ning
# ing
# ng a
# g al
#  alg
# algo
# lgor
# gori
# orit
# rith
# ithm
# thms
# hms
# ms i
# s in
#  inc
# incl
# nclu
# clud
# lude
# ude
# de t
# e th
#  the
# the
# he f
# e fo
#  fol
# foll
# ollo
# llow
# lowi
# owin

# %%
for i in range(200):
  if curr_sequence not in ngrams.keys():
    break
  possible_chars = ngrams[curr_sequence]
  next_char = possible_chars[random.randrange(len(possible_chars))]
  output += next_char
  curr_sequence = output[len(output)-chars:len(output)]

print(output)
# Out:
# maching is of its own programmercial neural learning or deep learning cinematicalled tasks in make a decades that observed during datage of data mining data biases to considered tasks by thematical real neural neurons of exact feature. the nuance of value without the graph computers medictables in theft of machine learning methods and a feature validated to teach machine learning train.  in techniques have and regressed as image classify a centrast w

# %% [markdown]
# **WORD N-GRAM**

# %%
ngrams = {}
words = 4
words_tokens = nltk.word_tokenize(article_text)

# %%
for i in range(len(words_tokens)-words):
  seq = ' '.join(words_tokens[i:i+words])
  print(seq)
  if seq not in ngrams.keys():
    ngrams[seq] = []
  ngrams[seq].append(words_tokens[i+words])
curr_sequence = ' '.join(words_tokens[0:words])
output = curr_sequence
# Out:
# machine learning ml is
# learning ml is a
# ml is a field
# is a field of
# a field of inquiry
# field of inquiry devoted
# of inquiry devoted to
# inquiry devoted to understanding
# devoted to understanding and
# to understanding and building
# understanding and building methods
# and building methods that
# building methods that learn
# methods that learn that
# that learn that is
# learn that is methods
# that is methods that
# is methods that leverage
# methods that leverage data
# that leverage data to
# leverage data to improve
# data to improve performance
# to improve performance on
# improve performance on some
# performance on some set
# on some set of
# some set of tasks
# set of tasks .
# of tasks . it
# tasks . it is
# . it is seen
# it is seen as
# is seen as a
# seen as a part
# as a part of
# a part of artificial
# part of artificial intelligence
# of artificial intelligence .
# artificial intelligence . machine
# intelligence . machine learning
# . machine learning algorithms
# machine learning algorithms build
# learning algorithms build a
# algorithms build a model
# build a model based
# a model based on
# model based on sample
# based on sample data
# on sample data known
# sample data known as
# data known as training
# known as training data
# as training data in
# training data in order
# data in order to
# in order to make
# order to make predictions
# to make predictions or
# make predictions or decisions
# predictions or decisions without
# or decisions without being
# decisions without being explicitly
# without being explicitly programmed
# being explicitly programmed to
# explicitly programmed to do
# programmed to do so
# to do so .
# do so . machine
# so . machine learning
# . machine learning algorithms
# machine learning algorithms are
# learning algorithms are used
# algorithms are used in
# are used in a
# used in a wide
# in a wide variety
# a wide variety of
# wide variety of applications
# variety of applications such
# of applications such as
# applications such as in
# such as in medicine
# as in medicine email
# in medicine email filtering
# medicine email filtering speech
# email filtering speech recognition
# filtering speech recognition and
# speech recognition and computer
# recognition and computer vision
# and computer vision where
# computer vision where it
# vision where it is
# where it is difficult
# it is difficult or
# is difficult or unfeasible
# difficult or unfeasible to
# or unfeasible to develop
# unfeasible to develop conventional
# to develop conventional algorithms
# develop conventional algorithms to
# conventional algorithms to perform
# algorithms to perform the
# to perform the needed
# perform the needed tasks.a
# the needed tasks.a subset
# needed tasks.a subset of
# tasks.a subset of machine
# subset of machine learning
# of machine learning is
# machine learning is closely
# learning is closely related
# is closely related to
# closely related to computational
# related to computational statistics
# to computational statistics which
# computational statistics which focuses
# statistics which focuses on
# which focuses on making
# focuses on making predictions
# on making predictions using
# making predictions using computers
# predictions using computers but
# using computers but not
# computers but not all
# but not all machine
# not all machine learning
# all machine learning is
# machine learning is statistical
# learning is statistical learning
# is statistical learning .
# statistical learning . the
# learning . the study
# . the study of
# the study of mathematical
# study of mathematical optimization
# of mathematical optimization delivers
# mathematical optimization delivers methods
# optimization delivers methods theory
# delivers methods theory and
# methods theory and application
# theory and application domains
# and application domains to
# application domains to the
# domains to the field
# to the field of
# the field of machine
# field of machine learning
# of machine learning .
# machine learning . data
# learning . data mining
# . data mining is
# data mining is a
# mining is a related
# is a related field
# a related field of
# related field of study
# field of study focusing
# of study focusing on
# study focusing on exploratory
# focusing on exploratory data
# on exploratory data analysis
# exploratory data analysis through
# data analysis through unsupervised
# analysis through unsupervised learning
# through unsupervised learning .
# unsupervised learning . some
# learning . some implementations
# . some implementations of
# some implementations of machine
# implementations of machine learning
# of machine learning use
# machine learning use data
# learning use data and
# use data and neural
# data and neural networks
# and neural networks in
# neural networks in a
# networks in a way
# in a way that
# a way that mimics
# way that mimics the
# that mimics the working
# mimics the working of
# the working of a
# working of a biological
# of a biological brain
# a biological brain .
# biological brain . in
# brain . in its
# . in its application
# in its application across
# its application across business
# application across business problems
# across business problems machine
# business problems machine learning
# problems machine learning is
# machine learning is also
# learning is also referred
# is also referred to
# also referred to as
# referred to as predictive
# to as predictive analytics.learning
# as predictive analytics.learning algorithms
# predictive analytics.learning algorithms work
# analytics.learning algorithms work on
# algorithms work on the
# work on the basis
# on the basis that
# the basis that strategies
# basis that strategies algorithms
# that strategies algorithms and
# strategies algorithms and inferences
# algorithms and inferences that
# and inferences that worked
# inferences that worked well
# that worked well in
# worked well in the
# well in the past
# in the past are
# the past are likely
# past are likely to
# are likely to continue
# likely to continue working
# to continue working well
# continue working well in
# working well in the
# well in the future
# in the future .
# the future . these
# future . these inferences
# . these inferences can
# these inferences can be
# inferences can be obvious
# can be obvious such
# be obvious such as
# obvious such as since
# such as since the
# as since the sun
# since the sun rose
# the sun rose every
# sun rose every morning
# rose every morning for
# every morning for the
# morning for the last
# for the last days
# the last days it
# last days it will
# days it will probably
# it will probably rise
# will probably rise tomorrow
# probably rise tomorrow morning
# rise tomorrow morning as
# tomorrow morning as well
# morning as well .
# as well . they
# well . they can
# . they can be
# they can be nuanced
# can be nuanced such
# be nuanced such as
# nuanced such as x
# such as x of
# as x of families
# x of families have
# of families have geographically
# families have geographically separate
# have geographically separate species
# geographically separate species with
# separate species with color
# species with color variants
# with color variants so
# color variants so there
# variants so there is
# so there is a
# there is a y
# is a y chance
# a y chance that
# y chance that undiscovered
# chance that undiscovered black
# that undiscovered black swans
# undiscovered black swans exist.machine
# black swans exist.machine learning
# swans exist.machine learning programs
# exist.machine learning programs can
# learning programs can perform
# programs can perform tasks
# can perform tasks without
# perform tasks without being
# tasks without being explicitly
# without being explicitly programmed
# being explicitly programmed to
# explicitly programmed to do
# programmed to do so
# to do so .
# do so . it
# so . it involves
# . it involves computers
# it involves computers learning
# involves computers learning from
# computers learning from data
# learning from data provided
# from data provided so
# data provided so that
# provided so that they
# so that they carry
# that they carry out
# they carry out certain
# carry out certain tasks
# out certain tasks .
# certain tasks . for
# tasks . for simple
# . for simple tasks
# for simple tasks assigned
# simple tasks assigned to
# tasks assigned to computers
# assigned to computers it
# to computers it is
# computers it is possible
# it is possible to
# is possible to program
# possible to program algorithms
# to program algorithms telling
# program algorithms telling the
# algorithms telling the machine
# telling the machine how
# the machine how to
# machine how to execute
# how to execute all
# to execute all steps
# execute all steps required
# all steps required to
# steps required to solve
# required to solve the
# to solve the problem
# solve the problem at
# the problem at hand
# problem at hand on
# at hand on the
# hand on the computers
# on the computers part
# the computers part no
# computers part no learning
# part no learning is
# no learning is needed
# learning is needed .
# is needed . for
# needed . for more
# . for more advanced
# for more advanced tasks
# more advanced tasks it
# advanced tasks it can
# tasks it can be
# it can be challenging
# can be challenging for
# be challenging for a
# challenging for a human
# for a human to
# a human to manually
# human to manually create
# to manually create the
# manually create the needed
# create the needed algorithms
# the needed algorithms .
# needed algorithms . in
# algorithms . in practice
# . in practice it
# in practice it can
# practice it can turn
# it can turn out
# can turn out to
# turn out to be
# out to be more
# to be more effective
# be more effective to
# more effective to help
# effective to help the
# to help the machine
# help the machine develop
# the machine develop its
# machine develop its own
# develop its own algorithm
# its own algorithm rather
# own algorithm rather than
# algorithm rather than having
# rather than having human
# than having human programmers
# having human programmers specify
# human programmers specify every
# programmers specify every needed
# specify every needed step.the
# every needed step.the discipline
# needed step.the discipline of
# step.the discipline of machine
# discipline of machine learning
# of machine learning employs
# machine learning employs various
# learning employs various approaches
# employs various approaches to
# various approaches to teach
# approaches to teach computers
# to teach computers to
# teach computers to accomplish
# computers to accomplish tasks
# to accomplish tasks where
# accomplish tasks where no
# tasks where no fully
# where no fully satisfactory
# no fully satisfactory algorithm
# fully satisfactory algorithm is
# satisfactory algorithm is available
# algorithm is available .
# is available . in
# available . in cases
# . in cases where
# in cases where vast
# cases where vast numbers
# where vast numbers of
# vast numbers of potential
# numbers of potential answers
# of potential answers exist
# potential answers exist one
# answers exist one approach
# exist one approach is
# one approach is to
# approach is to label
# is to label some
# to label some of
# label some of the
# some of the correct
# of the correct answers
# the correct answers as
# correct answers as valid
# answers as valid .
# as valid . this
# valid . this can
# . this can then
# this can then be
# can then be used
# then be used as
# be used as training
# used as training data
# as training data for
# training data for the
# data for the computer
# for the computer to
# the computer to improve
# computer to improve the
# to improve the algorithms
# improve the algorithms it
# the algorithms it uses
# algorithms it uses to
# it uses to determine
# uses to determine correct
# to determine correct answers
# determine correct answers .
# correct answers . for
# answers . for example
# . for example to
# for example to train
# example to train a
# to train a system
# train a system for
# a system for the
# system for the task
# for the task of
# the task of digital
# task of digital character
# of digital character recognition
# digital character recognition the
# character recognition the mnist
# recognition the mnist dataset
# the mnist dataset of
# mnist dataset of handwritten
# dataset of handwritten digits
# of handwritten digits has
# handwritten digits has often
# digits has often been
# has often been used.the
# often been used.the term
# been used.the term machine
# used.the term machine learning
# term machine learning was
# machine learning was coined
# learning was coined in
# was coined in by
# coined in by arthur
# in by arthur samuel
# by arthur samuel an
# arthur samuel an ibm
# samuel an ibm employee
# an ibm employee and
# ibm employee and pioneer
# employee and pioneer in
# and pioneer in the
# pioneer in the field
# in the field of
# the field of computer
# field of computer gaming
# of computer gaming and
# computer gaming and artificial
# gaming and artificial intelligence
# and artificial intelligence .
# artificial intelligence . also
# intelligence . also the
# . also the synonym
# also the synonym selfteaching
# the synonym selfteaching computers
# synonym selfteaching computers were
# selfteaching computers were used
# computers were used in
# were used in this
# used in this time
# in this time period.by
# this time period.by the
# time period.by the early
# period.by the early s
# the early s an
# early s an experimental
# s an experimental learning
# an experimental learning machine
# experimental learning machine with
# learning machine with punched
# machine with punched tape
# with punched tape memory
# punched tape memory called
# tape memory called cybertron
# memory called cybertron had
# called cybertron had been
# cybertron had been developed
# had been developed by
# been developed by raytheon
# developed by raytheon company
# by raytheon company to
# raytheon company to analyze
# company to analyze sonar
# to analyze sonar signals
# analyze sonar signals electrocardiograms
# sonar signals electrocardiograms and
# signals electrocardiograms and speech
# electrocardiograms and speech patterns
# and speech patterns using
# speech patterns using rudimentary
# patterns using rudimentary reinforcement
# using rudimentary reinforcement learning
# rudimentary reinforcement learning .
# reinforcement learning . it
# learning . it was
# . it was repetitively
# it was repetitively trained
# was repetitively trained by
# repetitively trained by a
# trained by a human
# by a human operatorteacher
# a human operatorteacher to
# human operatorteacher to recognize
# operatorteacher to recognize patterns
# to recognize patterns and
# recognize patterns and equipped
# patterns and equipped with
# and equipped with a
# equipped with a goof
# with a goof button
# a goof button to
# goof button to cause
# button to cause it
# to cause it to
# cause it to reevaluate
# it to reevaluate incorrect
# to reevaluate incorrect decisions
# reevaluate incorrect decisions .
# incorrect decisions . a
# decisions . a representative
# . a representative book
# a representative book on
# representative book on research
# book on research into
# on research into machine
# research into machine learning
# into machine learning during
# machine learning during the
# learning during the s
# during the s was
# the s was nilssons
# s was nilssons book
# was nilssons book on
# nilssons book on learning
# book on learning machines
# on learning machines dealing
# learning machines dealing mostly
# machines dealing mostly with
# dealing mostly with machine
# mostly with machine learning
# with machine learning for
# machine learning for pattern
# learning for pattern classification
# for pattern classification .
# pattern classification . interest
# classification . interest related
# . interest related to
# interest related to pattern
# related to pattern recognition
# to pattern recognition continued
# pattern recognition continued into
# recognition continued into the
# continued into the s
# into the s as
# the s as described
# s as described by
# as described by duda
# described by duda and
# by duda and hart
# duda and hart in
# and hart in .
# hart in . in
# in . in a
# . in a report
# in a report was
# a report was given
# report was given on
# was given on using
# given on using teaching
# on using teaching strategies
# using teaching strategies so
# teaching strategies so that
# strategies so that a
# so that a neural
# that a neural network
# a neural network learns
# neural network learns to
# network learns to recognize
# learns to recognize characters
# to recognize characters letters
# recognize characters letters digits
# characters letters digits and
# letters digits and special
# digits and special symbols
# and special symbols from
# special symbols from a
# symbols from a computer
# from a computer terminal.tom
# a computer terminal.tom m.
# computer terminal.tom m. mitchell
# terminal.tom m. mitchell provided
# m. mitchell provided a
# mitchell provided a widely
# provided a widely quoted
# a widely quoted more
# widely quoted more formal
# quoted more formal definition
# more formal definition of
# formal definition of the
# definition of the algorithms
# of the algorithms studied
# the algorithms studied in
# algorithms studied in the
# studied in the machine
# in the machine learning
# the machine learning field
# machine learning field a
# learning field a computer
# field a computer program
# a computer program is
# computer program is said
# program is said to
# is said to learn
# said to learn from
# to learn from experience
# learn from experience e
# from experience e with
# experience e with respect
# e with respect to
# with respect to some
# respect to some class
# to some class of
# some class of tasks
# class of tasks t
# of tasks t and
# tasks t and performance
# t and performance measure
# and performance measure p
# performance measure p if
# measure p if its
# p if its performance
# if its performance at
# its performance at tasks
# performance at tasks in
# at tasks in t
# tasks in t as
# in t as measured
# t as measured by
# as measured by p
# measured by p improves
# by p improves with
# p improves with experience
# improves with experience e.
# with experience e. this
# experience e. this definition
# e. this definition of
# this definition of the
# definition of the tasks
# of the tasks in
# the tasks in which
# tasks in which machine
# in which machine learning
# which machine learning is
# machine learning is concerned
# learning is concerned offers
# is concerned offers a
# concerned offers a fundamentally
# offers a fundamentally operational
# a fundamentally operational definition
# fundamentally operational definition rather
# operational definition rather than
# definition rather than defining
# rather than defining the
# than defining the field
# defining the field in
# the field in cognitive
# field in cognitive terms
# in cognitive terms .
# cognitive terms . this
# terms . this follows
# . this follows alan
# this follows alan turings
# follows alan turings proposal
# alan turings proposal in
# turings proposal in his
# proposal in his paper
# in his paper computing
# his paper computing machinery
# paper computing machinery and
# computing machinery and intelligence
# machinery and intelligence in
# and intelligence in which
# intelligence in which the
# in which the question
# which the question can
# the question can machines
# question can machines think
# can machines think is
# machines think is replaced
# think is replaced with
# is replaced with the
# replaced with the question
# with the question can
# the question can machines
# question can machines do
# can machines do what
# machines do what we
# do what we as
# what we as thinking
# we as thinking entities
# as thinking entities can
# thinking entities can do.modern
# entities can do.modern day
# can do.modern day machine
# do.modern day machine learning
# day machine learning has
# machine learning has two
# learning has two objectives
# has two objectives one
# two objectives one is
# objectives one is to
# one is to classify
# is to classify data
# to classify data based
# classify data based on
# data based on models
# based on models which
# on models which have
# models which have been
# which have been developed
# have been developed the
# been developed the other
# developed the other purpose
# the other purpose is
# other purpose is to
# purpose is to make
# is to make predictions
# to make predictions for
# make predictions for future
# predictions for future outcomes
# for future outcomes based
# future outcomes based on
# outcomes based on these
# based on these models
# on these models .
# these models . a
# models . a hypothetical
# . a hypothetical algorithm
# a hypothetical algorithm specific
# hypothetical algorithm specific to
# algorithm specific to classifying
# specific to classifying data
# to classifying data may
# classifying data may use
# data may use computer
# may use computer vision
# use computer vision of
# computer vision of moles
# vision of moles coupled
# of moles coupled with
# moles coupled with supervised
# coupled with supervised learning
# with supervised learning in
# supervised learning in order
# learning in order to
# in order to train
# order to train it
# to train it to
# train it to classify
# it to classify the
# to classify the cancerous
# classify the cancerous moles
# the cancerous moles .
# cancerous moles . a
# moles . a machine
# . a machine learning
# a machine learning algorithm
# machine learning algorithm for
# learning algorithm for stock
# algorithm for stock trading
# for stock trading may
# stock trading may inform
# trading may inform the
# may inform the trader
# inform the trader of
# the trader of future
# trader of future potential
# of future potential predictions.as
# future potential predictions.as a
# potential predictions.as a scientific
# predictions.as a scientific endeavor
# a scientific endeavor machine
# scientific endeavor machine learning
# endeavor machine learning grew
# machine learning grew out
# learning grew out of
# grew out of the
# out of the quest
# of the quest for
# the quest for artificial
# quest for artificial intelligence
# for artificial intelligence .
# artificial intelligence . in
# intelligence . in the
# . in the early
# in the early days
# the early days of
# early days of ai
# days of ai as
# of ai as an
# ai as an academic
# as an academic discipline
# an academic discipline some
# academic discipline some researchers
# discipline some researchers were
# some researchers were interested
# researchers were interested in
# were interested in having
# interested in having machines
# in having machines learn
# having machines learn from
# machines learn from data
# learn from data .
# from data . they
# data . they attempted
# . they attempted to
# they attempted to approach
# attempted to approach the
# to approach the problem
# approach the problem with
# the problem with various
# problem with various symbolic
# with various symbolic methods
# various symbolic methods as
# symbolic methods as well
# methods as well as
# as well as what
# well as what was
# as what was then
# what was then termed
# was then termed neural
# then termed neural networks
# termed neural networks these
# neural networks these were
# networks these were mostly
# these were mostly perceptrons
# were mostly perceptrons and
# mostly perceptrons and other
# perceptrons and other models
# and other models that
# other models that were
# models that were later
# that were later found
# were later found to
# later found to be
# found to be reinventions
# to be reinventions of
# be reinventions of the
# reinventions of the generalized
# of the generalized linear
# the generalized linear models
# generalized linear models of
# linear models of statistics
# models of statistics .
# of statistics . probabilistic
# statistics . probabilistic reasoning
# . probabilistic reasoning was
# probabilistic reasoning was also
# reasoning was also employed
# was also employed especially
# also employed especially in
# employed especially in automated
# especially in automated medical
# in automated medical diagnosis.however
# automated medical diagnosis.however an
# medical diagnosis.however an increasing
# diagnosis.however an increasing emphasis
# an increasing emphasis on
# increasing emphasis on the
# emphasis on the logical
# on the logical knowledgebased
# the logical knowledgebased approach
# logical knowledgebased approach caused
# knowledgebased approach caused a
# approach caused a rift
# caused a rift between
# a rift between ai
# rift between ai and
# between ai and machine
# ai and machine learning
# and machine learning .
# machine learning . probabilistic
# learning . probabilistic systems
# . probabilistic systems were
# probabilistic systems were plagued
# systems were plagued by
# were plagued by theoretical
# plagued by theoretical and
# by theoretical and practical
# theoretical and practical problems
# and practical problems of
# practical problems of data
# problems of data acquisition
# of data acquisition and
# data acquisition and representation
# acquisition and representation .
# and representation . by
# representation . by expert
# . by expert systems
# by expert systems had
# expert systems had come
# systems had come to
# had come to dominate
# come to dominate ai
# to dominate ai and
# dominate ai and statistics
# ai and statistics was
# and statistics was out
# statistics was out of
# was out of favor
# out of favor .
# of favor . work
# favor . work on
# . work on symbolicknowledgebased
# work on symbolicknowledgebased learning
# on symbolicknowledgebased learning did
# symbolicknowledgebased learning did continue
# learning did continue within
# did continue within ai
# continue within ai leading
# within ai leading to
# ai leading to inductive
# leading to inductive logic
# to inductive logic programming
# inductive logic programming but
# logic programming but the
# programming but the more
# but the more statistical
# the more statistical line
# more statistical line of
# statistical line of research
# line of research was
# of research was now
# research was now outside
# was now outside the
# now outside the field
# outside the field of
# the field of ai
# field of ai proper
# of ai proper in
# ai proper in pattern
# proper in pattern recognition
# in pattern recognition and
# pattern recognition and information
# recognition and information retrieval
# and information retrieval .
# information retrieval . neural
# retrieval . neural networks
# . neural networks research
# neural networks research had
# networks research had been
# research had been abandoned
# had been abandoned by
# been abandoned by ai
# abandoned by ai and
# by ai and computer
# ai and computer science
# and computer science around
# computer science around the
# science around the same
# around the same time
# the same time .
# same time . this
# time . this line
# . this line too
# this line too was
# line too was continued
# too was continued outside
# was continued outside the
# continued outside the aics
# outside the aics field
# the aics field as
# aics field as connectionism
# field as connectionism by
# as connectionism by researchers
# connectionism by researchers from
# by researchers from other
# researchers from other disciplines
# from other disciplines including
# other disciplines including hopfield
# disciplines including hopfield rumelhart
# including hopfield rumelhart and
# hopfield rumelhart and hinton
# rumelhart and hinton .
# and hinton . their
# hinton . their main
# . their main success
# their main success came
# main success came in
# success came in the
# came in the mids
# in the mids with
# the mids with the
# mids with the reinvention
# with the reinvention of
# the reinvention of backpropagation.machine
# reinvention of backpropagation.machine learning
# of backpropagation.machine learning ml
# backpropagation.machine learning ml reorganized
# learning ml reorganized as
# ml reorganized as a
# reorganized as a separate
# as a separate field
# a separate field started
# separate field started to
# field started to flourish
# started to flourish in
# to flourish in the
# flourish in the s.
# in the s. the
# the s. the field
# s. the field changed
# the field changed its
# field changed its goal
# changed its goal from
# its goal from achieving
# goal from achieving artificial
# from achieving artificial intelligence
# achieving artificial intelligence to
# artificial intelligence to tackling
# intelligence to tackling solvable
# to tackling solvable problems
# tackling solvable problems of
# solvable problems of a
# problems of a practical
# of a practical nature
# a practical nature .
# practical nature . it
# nature . it shifted
# . it shifted focus
# it shifted focus away
# shifted focus away from
# focus away from the
# away from the symbolic
# from the symbolic approaches
# the symbolic approaches it
# symbolic approaches it had
# approaches it had inherited
# it had inherited from
# had inherited from ai
# inherited from ai and
# from ai and toward
# ai and toward methods
# and toward methods and
# toward methods and models
# methods and models borrowed
# and models borrowed from
# models borrowed from statistics
# borrowed from statistics fuzzy
# from statistics fuzzy logic
# statistics fuzzy logic and
# fuzzy logic and probability
# logic and probability theory.the
# and probability theory.the difference
# probability theory.the difference between
# theory.the difference between ml
# difference between ml and
# between ml and ai
# ml and ai is
# and ai is frequently
# ai is frequently misunderstood
# is frequently misunderstood .
# frequently misunderstood . ml
# misunderstood . ml learns
# . ml learns and
# ml learns and predicts
# learns and predicts based
# and predicts based on
# predicts based on passive
# based on passive observations
# on passive observations whereas
# passive observations whereas ai
# observations whereas ai implies
# whereas ai implies an
# ai implies an agent
# implies an agent interacting
# an agent interacting with
# agent interacting with the
# interacting with the environment
# with the environment to
# the environment to learn
# environment to learn and
# to learn and take
# learn and take actions
# and take actions that
# take actions that maximize
# actions that maximize its
# that maximize its chance
# maximize its chance of
# its chance of successfully
# chance of successfully achieving
# of successfully achieving its
# successfully achieving its goals.as
# achieving its goals.as of
# its goals.as of many
# goals.as of many sources
# of many sources continue
# many sources continue to
# sources continue to assert
# continue to assert that
# to assert that ml
# assert that ml remains
# that ml remains a
# ml remains a subfield
# remains a subfield of
# a subfield of ai
# subfield of ai .
# of ai . others
# ai . others have
# . others have the
# others have the view
# have the view that
# the view that not
# view that not all
# that not all ml
# not all ml is
# all ml is part
# ml is part of
# is part of ai
# part of ai but
# of ai but only
# ai but only an
# but only an intelligent
# only an intelligent subset
# an intelligent subset of
# intelligent subset of ml
# subset of ml should
# of ml should be
# ml should be considered
# should be considered ai.machine
# be considered ai.machine learning
# considered ai.machine learning and
# ai.machine learning and data
# learning and data mining
# and data mining often
# data mining often employ
# mining often employ the
# often employ the same
# employ the same methods
# the same methods and
# same methods and overlap
# methods and overlap significantly
# and overlap significantly but
# overlap significantly but while
# significantly but while machine
# but while machine learning
# while machine learning focuses
# machine learning focuses on
# learning focuses on prediction
# focuses on prediction based
# on prediction based on
# prediction based on known
# based on known properties
# on known properties learned
# known properties learned from
# properties learned from the
# learned from the training
# from the training data
# the training data data
# training data data mining
# data data mining focuses
# data mining focuses on
# mining focuses on the
# focuses on the discovery
# on the discovery of
# the discovery of previously
# discovery of previously unknown
# of previously unknown properties
# previously unknown properties in
# unknown properties in the
# properties in the data
# in the data this
# the data this is
# data this is the
# this is the analysis
# is the analysis step
# the analysis step of
# analysis step of knowledge
# step of knowledge discovery
# of knowledge discovery in
# knowledge discovery in databases
# discovery in databases .
# in databases . data
# databases . data mining
# . data mining uses
# data mining uses many
# mining uses many machine
# uses many machine learning
# many machine learning methods
# machine learning methods but
# learning methods but with
# methods but with different
# but with different goals
# with different goals on
# different goals on the
# goals on the other
# on the other hand
# the other hand machine
# other hand machine learning
# hand machine learning also
# machine learning also employs
# learning also employs data
# also employs data mining
# employs data mining methods
# data mining methods as
# mining methods as unsupervised
# methods as unsupervised learning
# as unsupervised learning or
# unsupervised learning or as
# learning or as a
# or as a preprocessing
# as a preprocessing step
# a preprocessing step to
# preprocessing step to improve
# step to improve learner
# to improve learner accuracy
# improve learner accuracy .
# learner accuracy . much
# accuracy . much of
# . much of the
# much of the confusion
# of the confusion between
# the confusion between these
# confusion between these two
# between these two research
# these two research communities
# two research communities which
# research communities which do
# communities which do often
# which do often have
# do often have separate
# often have separate conferences
# have separate conferences and
# separate conferences and separate
# conferences and separate journals
# and separate journals ecml
# separate journals ecml pkdd
# journals ecml pkdd being
# ecml pkdd being a
# pkdd being a major
# being a major exception
# a major exception comes
# major exception comes from
# exception comes from the
# comes from the basic
# from the basic assumptions
# the basic assumptions they
# basic assumptions they work
# assumptions they work with
# they work with in
# work with in machine
# with in machine learning
# in machine learning performance
# machine learning performance is
# learning performance is usually
# performance is usually evaluated
# is usually evaluated with
# usually evaluated with respect
# evaluated with respect to
# with respect to the
# respect to the ability
# to the ability to
# the ability to reproduce
# ability to reproduce known
# to reproduce known knowledge
# reproduce known knowledge while
# known knowledge while in
# knowledge while in knowledge
# while in knowledge discovery
# in knowledge discovery and
# knowledge discovery and data
# discovery and data mining
# and data mining kdd
# data mining kdd the
# mining kdd the key
# kdd the key task
# the key task is
# key task is the
# task is the discovery
# is the discovery of
# the discovery of previously
# discovery of previously unknown
# of previously unknown knowledge
# previously unknown knowledge .
# unknown knowledge . evaluated
# knowledge . evaluated with
# . evaluated with respect
# evaluated with respect to
# with respect to known
# respect to known knowledge
# to known knowledge an
# known knowledge an uninformed
# knowledge an uninformed unsupervised
# an uninformed unsupervised method
# uninformed unsupervised method will
# unsupervised method will easily
# method will easily be
# will easily be outperformed
# easily be outperformed by
# be outperformed by other
# outperformed by other supervised
# by other supervised methods
# other supervised methods while
# supervised methods while in
# methods while in a
# while in a typical
# in a typical kdd
# a typical kdd task
# typical kdd task supervised
# kdd task supervised methods
# task supervised methods can
# supervised methods can not
# methods can not be
# can not be used
# not be used due
# be used due to
# used due to the
# due to the unavailability
# to the unavailability of
# the unavailability of training
# unavailability of training data.machine
# of training data.machine learning
# training data.machine learning also
# data.machine learning also has
# learning also has intimate
# also has intimate ties
# has intimate ties to
# intimate ties to optimization
# ties to optimization many
# to optimization many learning
# optimization many learning problems
# many learning problems are
# learning problems are formulated
# problems are formulated as
# are formulated as minimization
# formulated as minimization of
# as minimization of some
# minimization of some loss
# of some loss function
# some loss function on
# loss function on a
# function on a training
# on a training set
# a training set of
# training set of examples
# set of examples .
# of examples . loss
# examples . loss functions
# . loss functions express
# loss functions express the
# functions express the discrepancy
# express the discrepancy between
# the discrepancy between the
# discrepancy between the predictions
# between the predictions of
# the predictions of the
# predictions of the model
# of the model being
# the model being trained
# model being trained and
# being trained and the
# trained and the actual
# and the actual problem
# the actual problem instances
# actual problem instances for
# problem instances for example
# instances for example in
# for example in classification
# example in classification one
# in classification one wants
# classification one wants to
# one wants to assign
# wants to assign a
# to assign a label
# assign a label to
# a label to instances
# label to instances and
# to instances and models
# instances and models are
# and models are trained
# models are trained to
# are trained to correctly
# trained to correctly predict
# to correctly predict the
# correctly predict the preassigned
# predict the preassigned labels
# the preassigned labels of
# preassigned labels of a
# labels of a set
# of a set of
# a set of examples.the
# set of examples.the difference
# of examples.the difference between
# examples.the difference between optimization
# difference between optimization and
# between optimization and machine
# optimization and machine learning
# and machine learning arises
# machine learning arises from
# learning arises from the
# arises from the goal
# from the goal of
# the goal of generalization
# goal of generalization while
# of generalization while optimization
# generalization while optimization algorithms
# while optimization algorithms can
# optimization algorithms can minimize
# algorithms can minimize the
# can minimize the loss
# minimize the loss on
# the loss on a
# loss on a training
# on a training set
# a training set machine
# training set machine learning
# set machine learning is
# machine learning is concerned
# learning is concerned with
# is concerned with minimizing
# concerned with minimizing the
# with minimizing the loss
# minimizing the loss on
# the loss on unseen
# loss on unseen samples
# on unseen samples .
# unseen samples . characterizing
# samples . characterizing the
# . characterizing the generalization
# characterizing the generalization of
# the generalization of various
# generalization of various learning
# of various learning algorithms
# various learning algorithms is
# learning algorithms is an
# algorithms is an active
# is an active topic
# an active topic of
# active topic of current
# topic of current research
# of current research especially
# current research especially for
# research especially for deep
# especially for deep learning
# for deep learning algorithms.machine
# deep learning algorithms.machine learning
# learning algorithms.machine learning and
# algorithms.machine learning and statistics
# learning and statistics are
# and statistics are closely
# statistics are closely related
# are closely related fields
# closely related fields in
# related fields in terms
# fields in terms of
# in terms of methods
# terms of methods but
# of methods but distinct
# methods but distinct in
# but distinct in their
# distinct in their principal
# in their principal goal
# their principal goal statistics
# principal goal statistics draws
# goal statistics draws population
# statistics draws population inferences
# draws population inferences from
# population inferences from a
# inferences from a sample
# from a sample while
# a sample while machine
# sample while machine learning
# while machine learning finds
# machine learning finds generalizable
# learning finds generalizable predictive
# finds generalizable predictive patterns
# generalizable predictive patterns .
# predictive patterns . according
# patterns . according to
# . according to michael
# according to michael i.
# to michael i. jordan
# michael i. jordan the
# i. jordan the ideas
# jordan the ideas of
# the ideas of machine
# ideas of machine learning
# of machine learning from
# machine learning from methodological
# learning from methodological principles
# from methodological principles to
# methodological principles to theoretical
# principles to theoretical tools
# to theoretical tools have
# theoretical tools have had
# tools have had a
# have had a long
# had a long prehistory
# a long prehistory in
# long prehistory in statistics
# prehistory in statistics .
# in statistics . he
# statistics . he also
# . he also suggested
# he also suggested the
# also suggested the term
# suggested the term data
# the term data science
# term data science as
# data science as a
# science as a placeholder
# as a placeholder to
# a placeholder to call
# placeholder to call the
# to call the overall
# call the overall field.leo
# the overall field.leo breiman
# overall field.leo breiman distinguished
# field.leo breiman distinguished two
# breiman distinguished two statistical
# distinguished two statistical modeling
# two statistical modeling paradigms
# statistical modeling paradigms data
# modeling paradigms data model
# paradigms data model and
# data model and algorithmic
# model and algorithmic model
# and algorithmic model wherein
# algorithmic model wherein algorithmic
# model wherein algorithmic model
# wherein algorithmic model means
# algorithmic model means more
# model means more or
# means more or less
# more or less the
# or less the machine
# less the machine learning
# the machine learning algorithms
# machine learning algorithms like
# learning algorithms like random
# algorithms like random forest.some
# like random forest.some statisticians
# random forest.some statisticians have
# forest.some statisticians have adopted
# statisticians have adopted methods
# have adopted methods from
# adopted methods from machine
# methods from machine learning
# from machine learning leading
# machine learning leading to
# learning leading to a
# leading to a combined
# to a combined field
# a combined field that
# combined field that they
# field that they call
# that they call statistical
# they call statistical learning.a
# call statistical learning.a core
# statistical learning.a core objective
# learning.a core objective of
# core objective of a
# objective of a learner
# of a learner is
# a learner is to
# learner is to generalize
# is to generalize from
# to generalize from its
# generalize from its experience
# from its experience .
# its experience . generalization
# experience . generalization in
# . generalization in this
# generalization in this context
# in this context is
# this context is the
# context is the ability
# is the ability of
# the ability of a
# ability of a learning
# of a learning machine
# a learning machine to
# learning machine to perform
# machine to perform accurately
# to perform accurately on
# perform accurately on new
# accurately on new unseen
# on new unseen examplestasks
# new unseen examplestasks after
# unseen examplestasks after having
# examplestasks after having experienced
# after having experienced a
# having experienced a learning
# experienced a learning data
# a learning data set
# learning data set .
# data set . the
# set . the training
# . the training examples
# the training examples come
# training examples come from
# examples come from some
# come from some generally
# from some generally unknown
# some generally unknown probability
# generally unknown probability distribution
# unknown probability distribution considered
# probability distribution considered representative
# distribution considered representative of
# considered representative of the
# representative of the space
# of the space of
# the space of occurrences
# space of occurrences and
# of occurrences and the
# occurrences and the learner
# and the learner has
# the learner has to
# learner has to build
# has to build a
# to build a general
# build a general model
# a general model about
# general model about this
# model about this space
# about this space that
# this space that enables
# space that enables it
# that enables it to
# enables it to produce
# it to produce sufficiently
# to produce sufficiently accurate
# produce sufficiently accurate predictions
# sufficiently accurate predictions in
# accurate predictions in new
# predictions in new cases.the
# in new cases.the computational
# new cases.the computational analysis
# cases.the computational analysis of
# computational analysis of machine
# analysis of machine learning
# of machine learning algorithms
# machine learning algorithms and
# learning algorithms and their
# algorithms and their performance
# and their performance is
# their performance is a
# performance is a branch
# is a branch of
# a branch of theoretical
# branch of theoretical computer
# of theoretical computer science
# theoretical computer science known
# computer science known as
# science known as computational
# known as computational learning
# as computational learning theory
# computational learning theory via
# learning theory via the
# theory via the probably
# via the probably approximately
# the probably approximately correct
# probably approximately correct learning
# approximately correct learning pac
# correct learning pac model
# learning pac model .
# pac model . because
# model . because training
# . because training sets
# because training sets are
# training sets are finite
# sets are finite and
# are finite and the
# finite and the future
# and the future is
# the future is uncertain
# future is uncertain learning
# is uncertain learning theory
# uncertain learning theory usually
# learning theory usually does
# theory usually does not
# usually does not yield
# does not yield guarantees
# not yield guarantees of
# yield guarantees of the
# guarantees of the performance
# of the performance of
# the performance of algorithms
# performance of algorithms .
# of algorithms . instead
# algorithms . instead probabilistic
# . instead probabilistic bounds
# instead probabilistic bounds on
# probabilistic bounds on the
# bounds on the performance
# on the performance are
# the performance are quite
# performance are quite common
# are quite common .
# quite common . the
# common . the biasvariance
# . the biasvariance decomposition
# the biasvariance decomposition is
# biasvariance decomposition is one
# decomposition is one way
# is one way to
# one way to quantify
# way to quantify generalization
# to quantify generalization error.for
# quantify generalization error.for the
# generalization error.for the best
# error.for the best performance
# the best performance in
# best performance in the
# performance in the context
# in the context of
# the context of generalization
# context of generalization the
# of generalization the complexity
# generalization the complexity of
# the complexity of the
# complexity of the hypothesis
# of the hypothesis should
# the hypothesis should match
# hypothesis should match the
# should match the complexity
# match the complexity of
# the complexity of the
# complexity of the function
# of the function underlying
# the function underlying the
# function underlying the data
# underlying the data .
# the data . if
# data . if the
# . if the hypothesis
# if the hypothesis is
# the hypothesis is less
# hypothesis is less complex
# is less complex than
# less complex than the
# complex than the function
# than the function then
# the function then the
# function then the model
# then the model has
# the model has under
# model has under fitted
# has under fitted the
# under fitted the data
# fitted the data .
# the data . if
# data . if the
# . if the complexity
# if the complexity of
# the complexity of the
# complexity of the model
# of the model is
# the model is increased
# model is increased in
# is increased in response
# increased in response then
# in response then the
# response then the training
# then the training error
# the training error decreases
# training error decreases .
# error decreases . but
# decreases . but if
# . but if the
# but if the hypothesis
# if the hypothesis is
# the hypothesis is too
# hypothesis is too complex
# is too complex then
# too complex then the
# complex then the model
# then the model is
# the model is subject
# model is subject to
# is subject to overfitting
# subject to overfitting and
# to overfitting and generalization
# overfitting and generalization will
# and generalization will be
# generalization will be poorer.in
# will be poorer.in addition
# be poorer.in addition to
# poorer.in addition to performance
# addition to performance bounds
# to performance bounds learning
# performance bounds learning theorists
# bounds learning theorists study
# learning theorists study the
# theorists study the time
# study the time complexity
# the time complexity and
# time complexity and feasibility
# complexity and feasibility of
# and feasibility of learning
# feasibility of learning .
# of learning . in
# learning . in computational
# . in computational learning
# in computational learning theory
# computational learning theory a
# learning theory a computation
# theory a computation is
# a computation is considered
# computation is considered feasible
# is considered feasible if
# considered feasible if it
# feasible if it can
# if it can be
# it can be done
# can be done in
# be done in polynomial
# done in polynomial time
# in polynomial time .
# polynomial time . there
# time . there are
# . there are two
# there are two kinds
# are two kinds of
# two kinds of time
# kinds of time complexity
# of time complexity results
# time complexity results positive
# complexity results positive results
# results positive results show
# positive results show that
# results show that a
# show that a certain
# that a certain class
# a certain class of
# certain class of functions
# class of functions can
# ...
# shows the numerators and
# the numerators and denominators
# numerators and denominators of
# and denominators of the
# denominators of the previously
# of the previously mentioned
# the previously mentioned rates
# previously mentioned rates thus
# mentioned rates thus toc
# rates thus toc provides
# thus toc provides more
# toc provides more information
# provides more information than
# more information than the
# information than the commonly
# than the commonly used
# the commonly used receiver
# commonly used receiver operating
# used receiver operating characteristic
# receiver operating characteristic roc
# operating characteristic roc and
# characteristic roc and rocs
# roc and rocs associated
# and rocs associated area
# rocs associated area under
# associated area under the
# area under the curve
# under the curve auc.machine
# the curve auc.machine learning
# curve auc.machine learning poses
# auc.machine learning poses a
# learning poses a host
# poses a host of
# a host of ethical
# host of ethical questions
# of ethical questions .
# ethical questions . systems
# questions . systems which
# . systems which are
# systems which are trained
# which are trained on
# are trained on datasets
# trained on datasets collected
# on datasets collected with
# datasets collected with biases
# collected with biases may
# with biases may exhibit
# biases may exhibit these
# may exhibit these biases
# exhibit these biases upon
# these biases upon use
# biases upon use algorithmic
# upon use algorithmic bias
# use algorithmic bias thus
# algorithmic bias thus digitizing
# bias thus digitizing cultural
# thus digitizing cultural prejudices
# digitizing cultural prejudices .
# cultural prejudices . for
# prejudices . for example
# . for example in
# for example in the
# example in the uks
# in the uks commission
# the uks commission for
# uks commission for racial
# commission for racial equality
# for racial equality found
# racial equality found that
# equality found that st.
# found that st. georges
# that st. georges medical
# st. georges medical school
# georges medical school had
# medical school had been
# school had been using
# had been using a
# been using a computer
# using a computer program
# a computer program trained
# computer program trained from
# program trained from data
# trained from data of
# from data of previous
# data of previous admissions
# of previous admissions staff
# previous admissions staff and
# admissions staff and this
# staff and this program
# and this program had
# this program had denied
# program had denied nearly
# had denied nearly candidates
# denied nearly candidates who
# nearly candidates who were
# candidates who were found
# who were found to
# were found to be
# found to be either
# to be either women
# be either women or
# either women or had
# women or had noneuropean
# or had noneuropean sounding
# had noneuropean sounding names
# noneuropean sounding names .
# sounding names . using
# names . using job
# . using job hiring
# using job hiring data
# job hiring data from
# hiring data from a
# data from a firm
# from a firm with
# a firm with racist
# firm with racist hiring
# with racist hiring policies
# racist hiring policies may
# hiring policies may lead
# policies may lead to
# may lead to a
# lead to a machine
# to a machine learning
# a machine learning system
# machine learning system duplicating
# learning system duplicating the
# system duplicating the bias
# duplicating the bias by
# the bias by scoring
# bias by scoring job
# by scoring job applicants
# scoring job applicants by
# job applicants by similarity
# applicants by similarity to
# by similarity to previous
# similarity to previous successful
# to previous successful applicants
# previous successful applicants .
# successful applicants . responsible
# applicants . responsible collection
# . responsible collection of
# responsible collection of data
# collection of data and
# of data and documentation
# data and documentation of
# and documentation of algorithmic
# documentation of algorithmic rules
# of algorithmic rules used
# algorithmic rules used by
# rules used by a
# used by a system
# by a system thus
# a system thus is
# system thus is a
# thus is a critical
# is a critical part
# a critical part of
# critical part of machine
# part of machine learning.ai
# of machine learning.ai can
# machine learning.ai can be
# learning.ai can be wellequipped
# can be wellequipped to
# be wellequipped to make
# wellequipped to make decisions
# to make decisions in
# make decisions in technical
# decisions in technical fields
# in technical fields which
# technical fields which rely
# fields which rely heavily
# which rely heavily on
# rely heavily on data
# heavily on data and
# on data and historical
# data and historical information
# and historical information .
# historical information . these
# information . these decisions
# . these decisions rely
# these decisions rely on
# decisions rely on the
# rely on the objectivity
# on the objectivity and
# the objectivity and logical
# objectivity and logical reasoning
# and logical reasoning .
# logical reasoning . because
# reasoning . because human
# . because human languages
# because human languages contain
# human languages contain biases
# languages contain biases machines
# contain biases machines trained
# biases machines trained on
# machines trained on language
# trained on language corpora
# on language corpora will
# language corpora will necessarily
# corpora will necessarily also
# will necessarily also learn
# necessarily also learn these
# also learn these biases.other
# learn these biases.other forms
# these biases.other forms of
# biases.other forms of ethical
# forms of ethical challenges
# of ethical challenges not
# ethical challenges not related
# challenges not related to
# not related to personal
# related to personal biases
# to personal biases are
# personal biases are seen
# biases are seen in
# are seen in health
# seen in health care
# in health care .
# health care . there
# care . there are
# . there are concerns
# there are concerns among
# are concerns among health
# concerns among health care
# among health care professionals
# health care professionals that
# care professionals that these
# professionals that these systems
# that these systems might
# these systems might not
# systems might not be
# might not be designed
# not be designed in
# be designed in the
# designed in the publics
# in the publics interest
# the publics interest but
# publics interest but as
# interest but as incomegenerating
# but as incomegenerating machines
# as incomegenerating machines .
# incomegenerating machines . this
# machines . this is
# . this is especially
# this is especially true
# is especially true in
# especially true in the
# true in the united
# in the united states
# the united states where
# united states where there
# states where there is
# where there is a
# there is a longstanding
# is a longstanding ethical
# a longstanding ethical dilemma
# longstanding ethical dilemma of
# ethical dilemma of improving
# dilemma of improving health
# of improving health care
# improving health care but
# health care but also
# care but also increase
# but also increase profits
# also increase profits .
# increase profits . for
# profits . for example
# . for example the
# for example the algorithms
# example the algorithms could
# the algorithms could be
# algorithms could be designed
# could be designed to
# be designed to provide
# designed to provide patients
# to provide patients with
# provide patients with unnecessary
# patients with unnecessary tests
# with unnecessary tests or
# unnecessary tests or medication
# tests or medication in
# or medication in which
# medication in which the
# in which the algorithms
# which the algorithms proprietary
# the algorithms proprietary owners
# algorithms proprietary owners hold
# proprietary owners hold stakes
# owners hold stakes .
# hold stakes . there
# stakes . there is
# . there is potential
# there is potential for
# is potential for machine
# potential for machine learning
# for machine learning in
# machine learning in health
# learning in health care
# in health care to
# health care to provide
# care to provide professionals
# to provide professionals an
# provide professionals an additional
# professionals an additional tool
# an additional tool to
# additional tool to diagnose
# tool to diagnose medicate
# to diagnose medicate and
# diagnose medicate and plan
# medicate and plan recovery
# and plan recovery paths
# plan recovery paths for
# recovery paths for patients
# paths for patients but
# for patients but this
# patients but this requires
# but this requires these
# this requires these biases
# requires these biases to
# these biases to be
# biases to be mitigated.since
# to be mitigated.since the
# be mitigated.since the s
# mitigated.since the s advances
# the s advances in
# s advances in both
# advances in both machine
# in both machine learning
# both machine learning algorithms
# machine learning algorithms and
# learning algorithms and computer
# algorithms and computer hardware
# and computer hardware have
# computer hardware have led
# hardware have led to
# have led to more
# led to more efficient
# to more efficient methods
# more efficient methods for
# efficient methods for training
# methods for training deep
# for training deep neural
# training deep neural networks
# deep neural networks a
# neural networks a particular
# networks a particular narrow
# a particular narrow subdomain
# particular narrow subdomain of
# narrow subdomain of machine
# subdomain of machine learning
# of machine learning that
# machine learning that contain
# learning that contain many
# that contain many layers
# contain many layers of
# many layers of nonlinear
# layers of nonlinear hidden
# of nonlinear hidden units
# nonlinear hidden units .
# hidden units . by
# units . by graphic
# . by graphic processing
# by graphic processing units
# graphic processing units gpus
# processing units gpus often
# units gpus often with
# gpus often with aispecific
# often with aispecific enhancements
# with aispecific enhancements had
# aispecific enhancements had displaced
# enhancements had displaced cpus
# had displaced cpus as
# displaced cpus as the
# cpus as the dominant
# as the dominant method
# the dominant method of
# dominant method of training
# method of training largescale
# of training largescale commercial
# training largescale commercial cloud
# largescale commercial cloud ai
# commercial cloud ai .
# cloud ai . openai
# ai . openai estimated
# . openai estimated the
# openai estimated the hardware
# estimated the hardware computing
# the hardware computing used
# hardware computing used in
# computing used in the
# used in the largest
# in the largest deep
# the largest deep learning
# largest deep learning projects
# deep learning projects from
# learning projects from alexnet
# projects from alexnet to
# from alexnet to alphazero
# alexnet to alphazero and
# to alphazero and found
# alphazero and found a
# and found a fold
# found a fold increase
# a fold increase in
# fold increase in the
# increase in the amount
# in the amount of
# the amount of compute
# amount of compute required
# of compute required with
# compute required with a
# required with a doublingtime
# with a doublingtime trendline
# a doublingtime trendline of
# doublingtime trendline of .
# trendline of . months.a
# of . months.a physical
# . months.a physical neural
# months.a physical neural network
# physical neural network or
# neural network or neuromorphic
# network or neuromorphic computer
# or neuromorphic computer is
# neuromorphic computer is a
# computer is a type
# is a type of
# a type of artificial
# type of artificial neural
# of artificial neural network
# artificial neural network in
# neural network in which
# network in which an
# in which an electrically
# which an electrically adjustable
# an electrically adjustable material
# electrically adjustable material is
# adjustable material is used
# material is used to
# is used to emulate
# used to emulate the
# to emulate the function
# emulate the function of
# the function of a
# function of a neural
# of a neural synapse
# a neural synapse .
# neural synapse . physical
# synapse . physical neural
# . physical neural network
# physical neural network is
# neural network is used
# network is used to
# is used to emphasize
# used to emphasize the
# to emphasize the reliance
# emphasize the reliance on
# the reliance on physical
# reliance on physical hardware
# on physical hardware used
# physical hardware used to
# hardware used to emulate
# used to emulate neurons
# to emulate neurons as
# emulate neurons as opposed
# neurons as opposed to
# as opposed to softwarebased
# opposed to softwarebased approaches
# to softwarebased approaches .
# softwarebased approaches . more
# approaches . more generally
# . more generally the
# more generally the term
# generally the term is
# the term is applicable
# term is applicable to
# is applicable to other
# applicable to other artificial
# to other artificial neural
# other artificial neural networks
# artificial neural networks in
# neural networks in which
# networks in which a
# in which a memristor
# which a memristor or
# a memristor or other
# memristor or other electrically
# or other electrically adjustable
# other electrically adjustable resistance
# electrically adjustable resistance material
# adjustable resistance material is
# resistance material is used
# material is used to
# is used to emulate
# used to emulate a
# to emulate a neural
# emulate a neural synapse.embedded
# a neural synapse.embedded machine
# neural synapse.embedded machine learning
# synapse.embedded machine learning is
# machine learning is a
# learning is a subfield
# is a subfield of
# a subfield of machine
# subfield of machine learning
# of machine learning where
# machine learning where the
# learning where the machine
# where the machine learning
# the machine learning model
# machine learning model is
# learning model is run
# model is run on
# is run on embedded
# run on embedded systems
# on embedded systems with
# embedded systems with limited
# systems with limited computing
# with limited computing resources
# limited computing resources such
# computing resources such as
# resources such as wearable
# such as wearable computers
# as wearable computers edge
# wearable computers edge devices
# computers edge devices and
# edge devices and microcontrollers
# devices and microcontrollers .
# and microcontrollers . running
# microcontrollers . running machine
# . running machine learning
# running machine learning model
# machine learning model in
# learning model in embedded
# model in embedded devices
# in embedded devices removes
# embedded devices removes the
# devices removes the need
# removes the need for
# the need for transferring
# need for transferring and
# for transferring and storing
# transferring and storing data
# and storing data on
# storing data on cloud
# data on cloud servers
# on cloud servers for
# cloud servers for further
# servers for further processing
# for further processing henceforth
# further processing henceforth reducing
# processing henceforth reducing data
# henceforth reducing data breaches
# reducing data breaches and
# data breaches and privacy
# breaches and privacy leaks
# and privacy leaks happening
# privacy leaks happening because
# leaks happening because of
# happening because of transferring
# because of transferring data
# of transferring data and
# transferring data and also
# data and also minimizes
# and also minimizes theft
# also minimizes theft of
# minimizes theft of intellectual
# theft of intellectual properties
# of intellectual properties personal
# intellectual properties personal data
# properties personal data and
# personal data and business
# data and business secrets
# and business secrets .
# business secrets . embedded
# secrets . embedded machine
# . embedded machine learning
# embedded machine learning could
# machine learning could be
# learning could be applied
# could be applied through
# be applied through several
# applied through several techniques
# through several techniques including
# several techniques including hardware
# techniques including hardware acceleration
# including hardware acceleration using
# hardware acceleration using approximate
# acceleration using approximate computing
# using approximate computing optimization
# approximate computing optimization of
# computing optimization of machine
# optimization of machine learning
# of machine learning models
# machine learning models and
# learning models and many
# models and many more.software
# and many more.software suites
# many more.software suites containing
# more.software suites containing a
# suites containing a variety
# containing a variety of
# a variety of machine
# variety of machine learning
# of machine learning algorithms
# machine learning algorithms include
# learning algorithms include the

# %%
for i in range(50):
  if curr_sequence not in ngrams.keys():
    break
  possible_words = ngrams[curr_sequence]
  next_word = possible_words[random.randrange(len(possible_words))]
  output += ' ' + next_word
  seq_words = nltk.word_tokenize(output)
  curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])

# %%
print(output)
# Out:
# machine learning ml is a field of inquiry devoted to understanding and building methods that learn that is methods that leverage data to improve performance on some set of tasks . it is seen as a part of artificial intelligence . machine learning algorithms build a model based on sample data known as training
